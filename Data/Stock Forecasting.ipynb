# %%
# !pip install nsepy
# Out:
# Requirement already satisfied: nsepy in c:\users\shriprada\anaconda3\lib\site-packages (0.8)
# Requirement already satisfied: beautifulsoup4 in c:\users\shriprada\anaconda3\lib\site-packages (from nsepy) (4.11.1)
# Requirement already satisfied: six in c:\users\shriprada\anaconda3\lib\site-packages (from nsepy) (1.16.0)
# Requirement already satisfied: numpy in c:\users\shriprada\anaconda3\lib\site-packages (from nsepy) (1.21.5)
# Requirement already satisfied: lxml in c:\users\shriprada\anaconda3\lib\site-packages (from nsepy) (4.8.0)
# Requirement already satisfied: click in c:\users\shriprada\anaconda3\lib\site-packages (from nsepy) (8.0.4)
# Requirement already satisfied: requests in c:\users\shriprada\anaconda3\lib\site-packages (from nsepy) (2.27.1)
# Requirement already satisfied: pandas in c:\users\shriprada\anaconda3\lib\site-packages (from nsepy) (1.4.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\shriprada\anaconda3\lib\site-packages (from beautifulsoup4->nsepy) (2.3.1)
# Requirement already satisfied: colorama in c:\users\shriprada\anaconda3\lib\site-packages (from click->nsepy) (0.4.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\shriprada\anaconda3\lib\site-packages (from pandas->nsepy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shriprada\anaconda3\lib\site-packages (from pandas->nsepy) (2021.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shriprada\anaconda3\lib\site-packages (from requests->nsepy) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shriprada\anaconda3\lib\site-packages (from requests->nsepy) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\shriprada\anaconda3\lib\site-packages (from requests->nsepy) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\shriprada\anaconda3\lib\site-packages (from requests->nsepy) (1.26.9)

# %%
from nsepy import get_history
from datetime import date
import pandas as pd

# %%
start_date_W = date(2012, 10, 1)
end_date_W = date(2022,10,15)

Wipro = get_history(symbol = 'WIPRO', start = start_date_W, end = end_date_W)
print(Wipro)
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2012-10-01  WIPRO     EQ      381.05  379.00  386.40  377.50  384.30  382.70
# 2012-10-03  WIPRO     EQ      382.70  384.25  387.25  379.20  380.40  380.25
# 2012-10-04  WIPRO     EQ      380.25  382.00  385.00  378.55  383.50  382.90
# 2012-10-05  WIPRO     EQ      382.90  383.55  384.60  320.50  373.00  373.25
# 2012-10-08  WIPRO     EQ      373.25  372.00  372.90  363.75  364.70  365.40
# ...           ...    ...         ...     ...     ...     ...     ...     ...
# 2022-10-10  WIPRO     EQ      408.10  400.30  413.50  399.75  412.90  411.30
# 2022-10-11  WIPRO     EQ      411.30  414.90  417.90  402.30  403.00  404.40
# 2022-10-12  WIPRO     EQ      404.40  404.25  409.60  401.60  408.55  407.95
# 2022-10-13  WIPRO     EQ      407.95  387.00  392.35  378.10  379.60  379.10
# 2022-10-14  WIPRO     EQ      379.10  387.00  387.50  376.25  377.80  377.30
#
#               VWAP    Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2012-10-01  382.83   1358933  5.202366e+13   15222             1015412
# 2012-10-03  382.12   2132629  8.149107e+13   24785             1820725
# 2012-10-04  382.21   1427363  5.455514e+13   17683             1037133
# 2012-10-05  371.85   1934963  7.195187e+13   20303              739766
# 2012-10-08  366.35    961564  3.522713e+13   21459              544630
# ...            ...       ...           ...     ...                 ...
# 2022-10-10  406.79   9357463  3.806536e+14  134498             5392290
# 2022-10-11  410.92  11361646  4.668742e+14  182559             3252451
# 2022-10-12  406.21   6305059  2.561150e+14   87449             1320130
# 2022-10-13  382.87  42448106  1.625222e+15  618958            18592824
# 2022-10-14  381.36  13932397  5.313307e+14  230005             4465571
#
#             %Deliverble
# Date
# 2012-10-01       0.7472
# 2012-10-03       0.8537
# 2012-10-04       0.7266
# 2012-10-05       0.3823
# 2012-10-08       0.5664
# ...                 ...
# 2022-10-10       0.5763
# 2022-10-11       0.2863
# 2022-10-12       0.2094
# 2022-10-13       0.4380
# 2022-10-14       0.3205
#
# [2484 rows x 14 columns]

# %%
stock_W = pd.DataFrame(Wipro)
stock_W
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2012-10-01  WIPRO     EQ      381.05  379.00  386.40  377.50  384.30  382.70
# 2012-10-03  WIPRO     EQ      382.70  384.25  387.25  379.20  380.40  380.25
# 2012-10-04  WIPRO     EQ      380.25  382.00  385.00  378.55  383.50  382.90
# 2012-10-05  WIPRO     EQ      382.90  383.55  384.60  320.50  373.00  373.25
# 2012-10-08  WIPRO     EQ      373.25  372.00  372.90  363.75  364.70  365.40
# ...           ...    ...         ...     ...     ...     ...     ...     ...
# 2022-10-10  WIPRO     EQ      408.10  400.30  413.50  399.75  412.90  411.30
# 2022-10-11  WIPRO     EQ      411.30  414.90  417.90  402.30  403.00  404.40
# 2022-10-12  WIPRO     EQ      404.40  404.25  409.60  401.60  408.55  407.95
# 2022-10-13  WIPRO     EQ      407.95  387.00  392.35  378.10  379.60  379.10
# 2022-10-14  WIPRO     EQ      379.10  387.00  387.50  376.25  377.80  377.30
#
#               VWAP    Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2012-10-01  382.83   1358933  5.202366e+13   15222             1015412
# 2012-10-03  382.12   2132629  8.149107e+13   24785             1820725
# 2012-10-04  382.21   1427363  5.455514e+13   17683             1037133
# 2012-10-05  371.85   1934963  7.195187e+13   20303              739766
# 2012-10-08  366.35    961564  3.522713e+13   21459              544630
# ...            ...       ...           ...     ...                 ...
# 2022-10-10  406.79   9357463  3.806536e+14  134498             5392290
# 2022-10-11  410.92  11361646  4.668742e+14  182559             3252451
# 2022-10-12  406.21   6305059  2.561150e+14   87449             1320130
# 2022-10-13  382.87  42448106  1.625222e+15  618958            18592824
# 2022-10-14  381.36  13932397  5.313307e+14  230005             4465571
#
#             %Deliverble
# Date
# 2012-10-01       0.7472
# 2012-10-03       0.8537
# 2012-10-04       0.7266
# 2012-10-05       0.3823
# 2012-10-08       0.5664
# ...                 ...
# 2022-10-10       0.5763
# 2022-10-11       0.2863
# 2022-10-12       0.2094
# 2022-10-13       0.4380
# 2022-10-14       0.3205
#
# [2484 rows x 14 columns]

# %% [markdown]
# ### Stocks of Infosys

# %%
start_date_I = date(2012, 10, 1)
end_date_I = date(2022,10,15)

Infosys = get_history(symbol = 'INFY', start = start_date_I, end = end_date_I)
print(Infosys)
# Out:
#            Symbol Series  Prev Close     Open     High      Low     Last  \
# Date
# 2012-10-01   INFY     EQ     2534.95  2551.30  2620.20  2549.00  2608.50
# 2012-10-03   INFY     EQ     2609.65  2605.25  2619.15  2560.50  2573.00
# 2012-10-04   INFY     EQ     2578.25  2575.10  2594.90  2557.05  2578.00
# 2012-10-05   INFY     EQ     2575.65  2585.00  2585.00  2060.55  2526.50
# 2012-10-08   INFY     EQ     2526.85  2524.80  2542.90  2460.00  2488.25
# ...           ...    ...         ...      ...      ...      ...      ...
# 2022-10-10   INFY     EQ     1451.20  1426.35  1465.00  1426.35  1465.00
# 2022-10-11   INFY     EQ     1462.65  1462.65  1479.65  1420.10  1425.00
# 2022-10-12   INFY     EQ     1423.80  1437.00  1441.10  1413.55  1430.00
# 2022-10-13   INFY     EQ     1428.70  1431.00  1437.95  1415.00  1422.00
# 2022-10-14   INFY     EQ     1419.90  1485.00  1494.00  1467.25  1477.00
#
#               Close     VWAP    Volume      Turnover  Trades  \
# Date
# 2012-10-01  2609.65  2592.48   1103286  2.860243e+14   48341
# 2012-10-03  2578.25  2586.82    977953  2.529788e+14   53428
# 2012-10-04  2575.65  2572.79    895535  2.304025e+14   37469
# 2012-10-05  2526.85  2515.49   1454000  3.657519e+14   53549
# 2012-10-08  2488.20  2500.87   1009680  2.525079e+14   80255
# ...             ...      ...       ...           ...     ...
# 2022-10-10  1462.65  1449.12   5274677  7.643649e+14  202762
# 2022-10-11  1423.80  1450.42  12824774  1.860130e+15  357001
# 2022-10-12  1428.70  1430.73   5481467  7.842490e+14  161320
# 2022-10-13  1419.90  1423.15   4821514  6.861726e+14  137929
# 2022-10-14  1474.25  1480.83  14990688  2.219873e+15  388421
#
#             Deliverable Volume  %Deliverble
# Date
# 2012-10-01              650073       0.5892
# 2012-10-03              507069       0.5185
# 2012-10-04              535868       0.5984
# 2012-10-05              527450       0.3628
# 2012-10-08              657600       0.6513
# ...                        ...          ...
# 2022-10-10             3428076       0.6499
# 2022-10-11             7613537       0.5937
# 2022-10-12             3246449       0.5923
# 2022-10-13             3000082       0.6222
# 2022-10-14             6427583       0.4288
#
# [2484 rows x 14 columns]

# %%
Stock_I = pd.DataFrame(Infosys)
Stock_I
# Out:
#            Symbol Series  Prev Close     Open     High      Low     Last  \
# Date
# 2012-10-01   INFY     EQ     2534.95  2551.30  2620.20  2549.00  2608.50
# 2012-10-03   INFY     EQ     2609.65  2605.25  2619.15  2560.50  2573.00
# 2012-10-04   INFY     EQ     2578.25  2575.10  2594.90  2557.05  2578.00
# 2012-10-05   INFY     EQ     2575.65  2585.00  2585.00  2060.55  2526.50
# 2012-10-08   INFY     EQ     2526.85  2524.80  2542.90  2460.00  2488.25
# ...           ...    ...         ...      ...      ...      ...      ...
# 2022-10-10   INFY     EQ     1451.20  1426.35  1465.00  1426.35  1465.00
# 2022-10-11   INFY     EQ     1462.65  1462.65  1479.65  1420.10  1425.00
# 2022-10-12   INFY     EQ     1423.80  1437.00  1441.10  1413.55  1430.00
# 2022-10-13   INFY     EQ     1428.70  1431.00  1437.95  1415.00  1422.00
# 2022-10-14   INFY     EQ     1419.90  1485.00  1494.00  1467.25  1477.00
#
#               Close     VWAP    Volume      Turnover  Trades  \
# Date
# 2012-10-01  2609.65  2592.48   1103286  2.860243e+14   48341
# 2012-10-03  2578.25  2586.82    977953  2.529788e+14   53428
# 2012-10-04  2575.65  2572.79    895535  2.304025e+14   37469
# 2012-10-05  2526.85  2515.49   1454000  3.657519e+14   53549
# 2012-10-08  2488.20  2500.87   1009680  2.525079e+14   80255
# ...             ...      ...       ...           ...     ...
# 2022-10-10  1462.65  1449.12   5274677  7.643649e+14  202762
# 2022-10-11  1423.80  1450.42  12824774  1.860130e+15  357001
# 2022-10-12  1428.70  1430.73   5481467  7.842490e+14  161320
# 2022-10-13  1419.90  1423.15   4821514  6.861726e+14  137929
# 2022-10-14  1474.25  1480.83  14990688  2.219873e+15  388421
#
#             Deliverable Volume  %Deliverble
# Date
# 2012-10-01              650073       0.5892
# 2012-10-03              507069       0.5185
# 2012-10-04              535868       0.5984
# 2012-10-05              527450       0.3628
# 2012-10-08              657600       0.6513
# ...                        ...          ...
# 2022-10-10             3428076       0.6499
# 2022-10-11             7613537       0.5937
# 2022-10-12             3246449       0.5923
# 2022-10-13             3000082       0.6222
# 2022-10-14             6427583       0.4288
#
# [2484 rows x 14 columns]

# %% [markdown]
# ### Stocks of Tata

# %%
start_date_T = date(2012, 10, 1)
end_date_T = date(2022,10,15)

Tata = get_history(symbol = 'TATAMOTORS', start = start_date_T, end = end_date_T)
Tata
# Out:
#                 Symbol Series  Prev Close    Open   High     Low    Last  \
# Date
# 2012-10-01  TATAMOTORS     EQ      267.55  268.00  276.2  268.00  274.45
# 2012-10-03  TATAMOTORS     EQ      274.70  275.00  276.0  270.20  273.00
# 2012-10-04  TATAMOTORS     EQ      273.50  275.25  279.0  273.15  273.35
# 2012-10-05  TATAMOTORS     EQ      274.30  276.50  282.5  219.45  281.50
# 2012-10-08  TATAMOTORS     EQ      280.55  281.45  283.7  271.00  271.95
# ...                ...    ...         ...     ...    ...     ...     ...
# 2022-10-10  TATAMOTORS     EQ      412.15  403.40  403.4  393.05  396.55
# 2022-10-11  TATAMOTORS     EQ      395.95  397.00  399.5  391.30  391.75
# 2022-10-12  TATAMOTORS     EQ      393.35  394.55  398.2  391.10  396.75
# 2022-10-13  TATAMOTORS     EQ      396.55  396.55  403.5  394.55  399.00
# 2022-10-14  TATAMOTORS     EQ      399.00  407.00  409.2  395.30  396.25
#
#              Close    VWAP    Volume      Turnover  Trades  \
# Date
# 2012-10-01  274.70  273.08   9420145  2.572465e+14   88596
# 2012-10-03  273.50  273.10   9136919  2.495328e+14   70558
# 2012-10-04  274.30  276.46   7581304  2.095891e+14   72562
# 2012-10-05  280.55  278.70  17095335  4.764485e+14  114300
# 2012-10-08  272.45  277.05   7590848  2.103010e+14   76338
# ...            ...     ...       ...           ...     ...
# 2022-10-10  395.95  396.05  32914630  1.303588e+15  383835
# 2022-10-11  393.35  396.08  14641301  5.799094e+14  187285
# 2022-10-12  396.55  394.96  14287344  5.642950e+14  170299
# 2022-10-13  399.00  398.20  12584114  5.011017e+14  142183
# 2022-10-14  396.25  401.55  12875470  5.170199e+14  135477
#
#             Deliverable Volume  %Deliverble
# Date
# 2012-10-01             4221642       0.4482
# 2012-10-03             3772453       0.4129
# 2012-10-04             3202071       0.4224
# 2012-10-05             6820337       0.3990
# 2012-10-08             2946526       0.3882
# ...                        ...          ...
# 2022-10-10            12262312       0.3725
# 2022-10-11             3677800       0.2512
# 2022-10-12             3002072       0.2101
# 2022-10-13             3624102       0.2880
# 2022-10-14             2634822       0.2046
#
# [2484 rows x 14 columns]

# %% [markdown]
# ### Stocks of RELIANCE

# %%
start_date_R = date(2012, 10, 1)
end_date_R = date(2022,10,15)

Reliance = get_history(symbol = 'RELIANCE', start = start_date_R, end = end_date_R)
Reliance
# Out:
#               Symbol Series  Prev Close     Open     High      Low     Last  \
# Date
# 2012-10-01  RELIANCE     EQ      837.20   840.00   842.30   829.25   834.10
# 2012-10-03  RELIANCE     EQ      833.50   834.45   853.45   834.25   847.45
# 2012-10-04  RELIANCE     EQ      846.10   850.55   858.90   849.10   852.00
# 2012-10-05  RELIANCE     EQ      852.90   859.90   862.00   682.35   859.55
# 2012-10-08  RELIANCE     EQ      857.80   854.55   854.55   816.25   817.00
# ...              ...    ...         ...      ...      ...      ...      ...
# 2022-10-10  RELIANCE     EQ     2432.35  2405.00  2417.60  2388.00  2407.00
# 2022-10-11  RELIANCE     EQ     2405.80  2414.00  2414.00  2351.10  2353.55
# 2022-10-12  RELIANCE     EQ     2357.90  2352.00  2381.70  2343.10  2377.00
# 2022-10-13  RELIANCE     EQ     2375.25  2371.40  2394.00  2360.10  2381.00
# 2022-10-14  RELIANCE     EQ     2382.80  2415.00  2416.35  2369.10  2371.75
#
#               Close     VWAP   Volume      Turnover  Trades  \
# Date
# 2012-10-01   833.50   834.99  1991469  1.662860e+14   49735
# 2012-10-03   846.10   845.93  5006639  4.235262e+14  110536
# 2012-10-04   852.90   853.87  2886232  2.464463e+14   70943
# 2012-10-05   857.80   846.95  3592138  3.042348e+14   60282
# 2012-10-08   819.40   828.39  4775793  3.956202e+14   96671
# ...             ...      ...      ...           ...     ...
# 2022-10-10  2405.80  2403.20  2921076  7.019928e+14  136725
# 2022-10-11  2357.90  2377.84  4252803  1.011249e+15  197213
# 2022-10-12  2375.25  2368.06  3422992  8.105861e+14  158484
# 2022-10-13  2382.80  2379.51  3382098  8.047737e+14  163282
# 2022-10-14  2370.70  2392.60  4202459  1.005482e+15  178804
#
#             Deliverable Volume  %Deliverble
# Date
# 2012-10-01              972193       0.4882
# 2012-10-03             2908157       0.5809
# 2012-10-04             1522797       0.5276
# 2012-10-05             1052935       0.2931
# 2012-10-08             2860535       0.5990
# ...                        ...          ...
# 2022-10-10             1453561       0.4976
# 2022-10-11             2480007       0.5831
# 2022-10-12             1914563       0.5593
# 2022-10-13             1976668       0.5845
# 2022-10-14             2676992       0.6370
#
# [2484 rows x 14 columns]

# %% [markdown]
# ### EDA on Wipro Data

# %%
stock_W
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2012-10-01  WIPRO     EQ      381.05  379.00  386.40  377.50  384.30  382.70
# 2012-10-03  WIPRO     EQ      382.70  384.25  387.25  379.20  380.40  380.25
# 2012-10-04  WIPRO     EQ      380.25  382.00  385.00  378.55  383.50  382.90
# 2012-10-05  WIPRO     EQ      382.90  383.55  384.60  320.50  373.00  373.25
# 2012-10-08  WIPRO     EQ      373.25  372.00  372.90  363.75  364.70  365.40
# ...           ...    ...         ...     ...     ...     ...     ...     ...
# 2022-10-10  WIPRO     EQ      408.10  400.30  413.50  399.75  412.90  411.30
# 2022-10-11  WIPRO     EQ      411.30  414.90  417.90  402.30  403.00  404.40
# 2022-10-12  WIPRO     EQ      404.40  404.25  409.60  401.60  408.55  407.95
# 2022-10-13  WIPRO     EQ      407.95  387.00  392.35  378.10  379.60  379.10
# 2022-10-14  WIPRO     EQ      379.10  387.00  387.50  376.25  377.80  377.30
#
#               VWAP    Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2012-10-01  382.83   1358933  5.202366e+13   15222             1015412
# 2012-10-03  382.12   2132629  8.149107e+13   24785             1820725
# 2012-10-04  382.21   1427363  5.455514e+13   17683             1037133
# 2012-10-05  371.85   1934963  7.195187e+13   20303              739766
# 2012-10-08  366.35    961564  3.522713e+13   21459              544630
# ...            ...       ...           ...     ...                 ...
# 2022-10-10  406.79   9357463  3.806536e+14  134498             5392290
# 2022-10-11  410.92  11361646  4.668742e+14  182559             3252451
# 2022-10-12  406.21   6305059  2.561150e+14   87449             1320130
# 2022-10-13  382.87  42448106  1.625222e+15  618958            18592824
# 2022-10-14  381.36  13932397  5.313307e+14  230005             4465571
#
#             %Deliverble
# Date
# 2012-10-01       0.7472
# 2012-10-03       0.8537
# 2012-10-04       0.7266
# 2012-10-05       0.3823
# 2012-10-08       0.5664
# ...                 ...
# 2022-10-10       0.5763
# 2022-10-11       0.2863
# 2022-10-12       0.2094
# 2022-10-13       0.4380
# 2022-10-14       0.3205
#
# [2484 rows x 14 columns]

# %%
stock_W.shape
# Out:
# (2484, 14)

# %%
stock_W.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2484 entries, 2012-10-01 to 2022-10-14
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Symbol              2484 non-null   object
#  1   Series              2484 non-null   object
#  2   Prev Close          2484 non-null   float64
#  3   Open                2484 non-null   float64
#  4   High                2484 non-null   float64
#  5   Low                 2484 non-null   float64
#  6   Last                2484 non-null   float64
#  7   Close               2484 non-null   float64
#  8   VWAP                2484 non-null   float64
#  9   Volume              2484 non-null   int64
#  10  Turnover            2484 non-null   float64
#  11  Trades              2484 non-null   int64
#  12  Deliverable Volume  2484 non-null   int64
#  13  %Deliverble         2484 non-null   float64
# dtypes: float64(9), int64(3), object(2)
# memory usage: 291.1+ KB

# %%
stock_W.reset_index(inplace = True)
stock_W.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2484 entries, 0 to 2483
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                2484 non-null   object
#  1   Symbol              2484 non-null   object
#  2   Series              2484 non-null   object
#  3   Prev Close          2484 non-null   float64
#  4   Open                2484 non-null   float64
#  5   High                2484 non-null   float64
#  6   Low                 2484 non-null   float64
#  7   Last                2484 non-null   float64
#  8   Close               2484 non-null   float64
#  9   VWAP                2484 non-null   float64
#  10  Volume              2484 non-null   int64
#  11  Turnover            2484 non-null   float64
#  12  Trades              2484 non-null   int64
#  13  Deliverable Volume  2484 non-null   int64
#  14  %Deliverble         2484 non-null   float64
# dtypes: float64(9), int64(3), object(3)
# memory usage: 291.2+ KB

# %%
stock_W['Date'] = pd.to_datetime(stock_W['Date'])
stock_W.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2484 entries, 0 to 2483
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                2484 non-null   datetime64[ns]
#  1   Symbol              2484 non-null   object
#  2   Series              2484 non-null   object
#  3   Prev Close          2484 non-null   float64
#  4   Open                2484 non-null   float64
#  5   High                2484 non-null   float64
#  6   Low                 2484 non-null   float64
#  7   Last                2484 non-null   float64
#  8   Close               2484 non-null   float64
#  9   VWAP                2484 non-null   float64
#  10  Volume              2484 non-null   int64
#  11  Turnover            2484 non-null   float64
#  12  Trades              2484 non-null   int64
#  13  Deliverable Volume  2484 non-null   int64
#  14  %Deliverble         2484 non-null   float64
# dtypes: datetime64[ns](1), float64(9), int64(3), object(2)
# memory usage: 291.2+ KB

# %%
stock_W.set_index('Date', inplace = True)
stock_W.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2484 entries, 2012-10-01 to 2022-10-14
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Symbol              2484 non-null   object
#  1   Series              2484 non-null   object
#  2   Prev Close          2484 non-null   float64
#  3   Open                2484 non-null   float64
#  4   High                2484 non-null   float64
#  5   Low                 2484 non-null   float64
#  6   Last                2484 non-null   float64
#  7   Close               2484 non-null   float64
#  8   VWAP                2484 non-null   float64
#  9   Volume              2484 non-null   int64
#  10  Turnover            2484 non-null   float64
#  11  Trades              2484 non-null   int64
#  12  Deliverable Volume  2484 non-null   int64
#  13  %Deliverble         2484 non-null   float64
# dtypes: float64(9), int64(3), object(2)
# memory usage: 291.1+ KB

# %%
stock_W.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  2484.000000  2484.000000  2484.000000  2484.000000  2484.000000
# mean    431.939855   432.257468   437.072464   426.930998   432.015217
# std     132.301302   132.517398   133.728751   131.025274   132.342090
# min     162.350000   163.100000   171.350000   159.400000   161.800000
# 25%     297.237500   297.112500   299.200000   294.325000   297.037500
# 50%     445.325000   443.700000   451.550000   437.575000   445.450000
# 75%     550.912500   550.100000   556.800000   544.212500   550.500000
# max     721.500000   722.750000   739.850000   716.000000   722.000000
#
#              Close         VWAP        Volume      Turnover         Trades  \
# count  2484.000000  2484.000000  2.484000e+03  2.484000e+03    2484.000000
# mean    431.938345   432.057874  4.645602e+06  1.896190e+14   63990.959340
# std     132.301904   132.331635  7.131907e+06  2.945919e+14   61714.435499
# min     162.350000   166.440000  5.213500e+04  1.850863e+12    1184.000000
# 25%     297.237500   296.960000  1.412974e+06  6.074737e+13   28932.750000
# 50%     445.325000   445.495000  2.524836e+06  9.959606e+13   45185.000000
# 75%     550.912500   551.007500  5.517814e+06  2.180364e+14   78007.000000
# max     721.500000   721.380000  1.303677e+08  5.075003e+15  793471.000000
#
#        Deliverable Volume  %Deliverble
# count        2.484000e+03  2484.000000
# mean         1.889645e+06     0.517157
# std          1.906071e+06     0.157415
# min          1.457300e+04     0.083600
# 25%          8.260558e+05     0.410075
# 50%          1.371343e+06     0.527450
# 75%          2.356628e+06     0.632825
# max          3.554140e+07     0.879400

# %%
stock_W.isnull().sum()
# Out:
# Symbol                0
# Series                0
# Prev Close            0
# Open                  0
# High                  0
# Low                   0
# Last                  0
# Close                 0
# VWAP                  0
# Volume                0
# Turnover              0
# Trades                0
# Deliverable Volume    0
# %Deliverble           0
# dtype: int64

# %%
W = stock_W.drop(columns =['Symbol', 'Series','VWAP','Volume','Turnover', 'Trades', 'Deliverable Volume', '%Deliverble'])
W
# Out:
#             Prev Close    Open    High     Low    Last   Close
# Date
# 2012-10-01      381.05  379.00  386.40  377.50  384.30  382.70
# 2012-10-03      382.70  384.25  387.25  379.20  380.40  380.25
# 2012-10-04      380.25  382.00  385.00  378.55  383.50  382.90
# 2012-10-05      382.90  383.55  384.60  320.50  373.00  373.25
# 2012-10-08      373.25  372.00  372.90  363.75  364.70  365.40
# ...                ...     ...     ...     ...     ...     ...
# 2022-10-10      408.10  400.30  413.50  399.75  412.90  411.30
# 2022-10-11      411.30  414.90  417.90  402.30  403.00  404.40
# 2022-10-12      404.40  404.25  409.60  401.60  408.55  407.95
# 2022-10-13      407.95  387.00  392.35  378.10  379.60  379.10
# 2022-10-14      379.10  387.00  387.50  376.25  377.80  377.30
#
# [2484 rows x 6 columns]

# %%
W.corr()
# Out:
#             Prev Close      Open      High       Low      Last     Close
# Prev Close    1.000000  0.998692  0.998253  0.998028  0.997601  0.997629
# Open          0.998692  1.000000  0.999418  0.999297  0.998809  0.998837
# High          0.998253  0.999418  1.000000  0.999241  0.999494  0.999524
# Low           0.998028  0.999297  0.999241  1.000000  0.999382  0.999429
# Last          0.997601  0.998809  0.999494  0.999382  1.000000  0.999966
# Close         0.997629  0.998837  0.999524  0.999429  0.999966  1.000000

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib import style
import math
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
plt.style.use('fivethirtyeight')

# %%
close_W = pd.DataFrame(W['Close'])
close_W
# Out:
#              Close
# Date
# 2012-10-01  382.70
# 2012-10-03  380.25
# 2012-10-04  382.90
# 2012-10-05  373.25
# 2012-10-08  365.40
# ...            ...
# 2022-10-10  411.30
# 2022-10-11  404.40
# 2022-10-12  407.95
# 2022-10-13  379.10
# 2022-10-14  377.30
#
# [2484 rows x 1 columns]

# %%
plt.figure(figsize=(16,8))
plt.title('Close Price History')
plt.plot(close_W)
plt.xlabel('Date', fontsize = 18)
plt.ylabel('Close Prise', fontsize = 18)
plt.show()

# %%
#moving average
ma100 = W.Close.rolling(100).mean()
ma100
# Out:
# Date
# 2012-10-01         NaN
# 2012-10-03         NaN
# 2012-10-04         NaN
# 2012-10-05         NaN
# 2012-10-08         NaN
#                 ...
# 2022-10-10    424.9905
# 2022-10-11    424.2220
# 2022-10-12    423.7900
# 2022-10-13    422.9850
# 2022-10-14    422.0980
# Name: Close, Length: 2484, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.plot(W.Close)
plt.plot(ma100, 'r')

# %%
plt.hist(close_W, bins = 10);

# %%
import seaborn as sns
from matplotlib import pyplot
from pandas.plotting import lag_plot

# %%
sns.boxplot(W['Close'])
# Out:
# C:\Users\Shriprada\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Close'>

# %%
W['Close'].plot(kind = 'kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
lag_plot(close_W)
pyplot.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(W.Close)
plt.plot(W.Open, 'r')

# %%
sns.heatmap(W.corr(), cmap = "YlGnBu")
# Out:
# <AxesSubplot:>

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
result = seasonal_decompose(close_W, model='multiplicative', period = 365)
fig = plt.figure()  
fig = result.plot()  
fig.set_size_inches(16, 9)

# %%
w_cumsum = W.cumsum()
w_cumsum.plot()
plt.title('Wipro Cumulative Returns')
# Out:
# Text(0.5, 1.0, 'Wipro Cumulative Returns')

# %%
w_cumsum = close_W.cumsum()
w_cumsum.plot()
plt.title('Wipro Cumulative Returns')
# Out:
# Text(0.5, 1.0, 'Wipro Cumulative Returns')

# %%
stock_W['Close'].resample(rule = 'M').mean().plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### EDA FOR INFOSYS

# %%
Stock_I
# Out:
#            Symbol Series  Prev Close     Open     High      Low     Last  \
# Date
# 2012-10-01   INFY     EQ     2534.95  2551.30  2620.20  2549.00  2608.50
# 2012-10-03   INFY     EQ     2609.65  2605.25  2619.15  2560.50  2573.00
# 2012-10-04   INFY     EQ     2578.25  2575.10  2594.90  2557.05  2578.00
# 2012-10-05   INFY     EQ     2575.65  2585.00  2585.00  2060.55  2526.50
# 2012-10-08   INFY     EQ     2526.85  2524.80  2542.90  2460.00  2488.25
# ...           ...    ...         ...      ...      ...      ...      ...
# 2022-10-10   INFY     EQ     1451.20  1426.35  1465.00  1426.35  1465.00
# 2022-10-11   INFY     EQ     1462.65  1462.65  1479.65  1420.10  1425.00
# 2022-10-12   INFY     EQ     1423.80  1437.00  1441.10  1413.55  1430.00
# 2022-10-13   INFY     EQ     1428.70  1431.00  1437.95  1415.00  1422.00
# 2022-10-14   INFY     EQ     1419.90  1485.00  1494.00  1467.25  1477.00
#
#               Close     VWAP    Volume      Turnover  Trades  \
# Date
# 2012-10-01  2609.65  2592.48   1103286  2.860243e+14   48341
# 2012-10-03  2578.25  2586.82    977953  2.529788e+14   53428
# 2012-10-04  2575.65  2572.79    895535  2.304025e+14   37469
# 2012-10-05  2526.85  2515.49   1454000  3.657519e+14   53549
# 2012-10-08  2488.20  2500.87   1009680  2.525079e+14   80255
# ...             ...      ...       ...           ...     ...
# 2022-10-10  1462.65  1449.12   5274677  7.643649e+14  202762
# 2022-10-11  1423.80  1450.42  12824774  1.860130e+15  357001
# 2022-10-12  1428.70  1430.73   5481467  7.842490e+14  161320
# 2022-10-13  1419.90  1423.15   4821514  6.861726e+14  137929
# 2022-10-14  1474.25  1480.83  14990688  2.219873e+15  388421
#
#             Deliverable Volume  %Deliverble
# Date
# 2012-10-01              650073       0.5892
# 2012-10-03              507069       0.5185
# 2012-10-04              535868       0.5984
# 2012-10-05              527450       0.3628
# 2012-10-08              657600       0.6513
# ...                        ...          ...
# 2022-10-10             3428076       0.6499
# 2022-10-11             7613537       0.5937
# 2022-10-12             3246449       0.5923
# 2022-10-13             3000082       0.6222
# 2022-10-14             6427583       0.4288
#
# [2484 rows x 14 columns]

# %%
I_Close = pd.DataFrame(Stock_I['Close'])
I_Close
# Out:
#               Close
# Date
# 2012-10-01  2609.65
# 2012-10-03  2578.25
# 2012-10-04  2575.65
# 2012-10-05  2526.85
# 2012-10-08  2488.20
# ...             ...
# 2022-10-10  1462.65
# 2022-10-11  1423.80
# 2022-10-12  1428.70
# 2022-10-13  1419.90
# 2022-10-14  1474.25
#
# [2484 rows x 1 columns]

# %%
Stock_I.shape
# Out:
# (2484, 14)

# %%
Stock_I.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  2484.000000  2484.000000  2484.000000  2484.000000  2484.000000
# mean   1584.869263  1584.449235  1600.794988  1568.067633  1584.523349
# std     895.334899   894.038407   902.638749   886.660668   895.117084
# min     526.450000   509.250000   558.000000   509.250000   529.150000
# 25%     956.250000   957.375000   966.675000   948.137500   956.037500
# 50%    1189.950000  1189.900000  1203.150000  1177.325000  1190.250000
# 75%    2012.037500  2009.225000  2036.612500  1986.000000  2007.375000
# max    4365.900000  4387.000000  4402.200000  4343.400000  4369.500000
#
#              Close         VWAP        Volume      Turnover        Trades  \
# count  2484.000000  2484.000000  2.484000e+03  2.484000e+03  2.484000e+03
# mean   1584.442250  1584.526465  5.190095e+06  6.155653e+14  1.324137e+05
# std     895.134512   894.686341  5.549143e+06  5.532964e+14  9.972396e+04
# min     526.450000   531.330000  2.580400e+04  6.098056e+12  1.709000e+03
# 25%     956.250000   956.412500  1.914723e+06  3.014009e+14  7.349000e+04
# 50%    1189.950000  1189.970000  3.918848e+06  4.634933e+14  1.108460e+05
# 75%    2009.400000  2012.937500  6.754096e+06  7.620525e+14  1.643945e+05
# max    4365.900000  4370.520000  9.043339e+07  8.323905e+15  1.643015e+06
#
#        Deliverable Volume  %Deliverble
# count        2.484000e+03  2484.000000
# mean         2.987748e+06     0.619413
# std          2.844470e+06     0.111866
# min          7.987000e+03     0.154600
# 25%          1.223142e+06     0.552375
# 50%          2.447769e+06     0.632850
# 75%          3.890334e+06     0.699025
# max          5.775916e+07     0.887000

# %%
Stock_I.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2484 entries, 2012-10-01 to 2022-10-14
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Symbol              2484 non-null   object
#  1   Series              2484 non-null   object
#  2   Prev Close          2484 non-null   float64
#  3   Open                2484 non-null   float64
#  4   High                2484 non-null   float64
#  5   Low                 2484 non-null   float64
#  6   Last                2484 non-null   float64
#  7   Close               2484 non-null   float64
#  8   VWAP                2484 non-null   float64
#  9   Volume              2484 non-null   int64
#  10  Turnover            2484 non-null   float64
#  11  Trades              2484 non-null   int64
#  12  Deliverable Volume  2484 non-null   int64
#  13  %Deliverble         2484 non-null   float64
# dtypes: float64(9), int64(3), object(2)
# memory usage: 291.1+ KB

# %%
Stock_I.isnull().sum()
# Out:
# Symbol                0
# Series                0
# Prev Close            0
# Open                  0
# High                  0
# Low                   0
# Last                  0
# Close                 0
# VWAP                  0
# Volume                0
# Turnover              0
# Trades                0
# Deliverable Volume    0
# %Deliverble           0
# dtype: int64

# %%
Stock_I.reset_index(inplace = True)

Stock_I['Date'] = pd.to_datetime(Stock_I['Date'])

Stock_I.set_index('Date', inplace = True)
Stock_I.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2484 entries, 2012-10-01 to 2022-10-14
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Symbol              2484 non-null   object
#  1   Series              2484 non-null   object
#  2   Prev Close          2484 non-null   float64
#  3   Open                2484 non-null   float64
#  4   High                2484 non-null   float64
#  5   Low                 2484 non-null   float64
#  6   Last                2484 non-null   float64
#  7   Close               2484 non-null   float64
#  8   VWAP                2484 non-null   float64
#  9   Volume              2484 non-null   int64
#  10  Turnover            2484 non-null   float64
#  11  Trades              2484 non-null   int64
#  12  Deliverable Volume  2484 non-null   int64
#  13  %Deliverble         2484 non-null   float64
# dtypes: float64(9), int64(3), object(2)
# memory usage: 291.1+ KB

# %%
Stock_I.corr()
# Out:
#                     Prev Close      Open      High       Low      Last  \
# Prev Close            1.000000  0.998223  0.998007  0.997891  0.997757
# Open                  0.998223  1.000000  0.999820  0.999720  0.999635
# High                  0.998007  0.999820  1.000000  0.999689  0.999836
# Low                   0.997891  0.999720  0.999689  1.000000  0.999798
# Last                  0.997757  0.999635  0.999836  0.999798  1.000000
# Close                 0.997764  0.999636  0.999843  0.999802  0.999992
# VWAP                  0.997934  0.999769  0.999913  0.999864  0.999948
# Volume               -0.415394 -0.416307 -0.413426 -0.419869 -0.416922
# Turnover             -0.148178 -0.148523 -0.144767 -0.153608 -0.149417
# Trades               -0.310328 -0.311974 -0.308868 -0.317133 -0.313568
# Deliverable Volume   -0.425812 -0.427702 -0.425891 -0.431070 -0.428924
# %Deliverble           0.280438  0.279082  0.274975  0.281765  0.277568
#
#                        Close      VWAP    Volume  Turnover    Trades  \
# Prev Close          0.997764  0.997934 -0.415394 -0.148178 -0.310328
# Open                0.999636  0.999769 -0.416307 -0.148523 -0.311974
# High                0.999843  0.999913 -0.413426 -0.144767 -0.308868
# Low                 0.999802  0.999864 -0.419869 -0.153608 -0.317133
# Last                0.999992  0.999948 -0.416922 -0.149417 -0.313568
# Close               1.000000  0.999956 -0.417104 -0.149661 -0.313720
# VWAP                0.999956  1.000000 -0.416743 -0.149192 -0.313211
# Volume             -0.417104 -0.416743  1.000000  0.866461  0.857528
# Turnover           -0.149661 -0.149192  0.866461  1.000000  0.844270
# Trades             -0.313720 -0.313211  0.857528  0.844270  1.000000
# Deliverable Volume -0.429132 -0.428697  0.921729  0.811013  0.814693
# %Deliverble         0.277573  0.277688 -0.363562 -0.271228 -0.308742
#
#                     Deliverable Volume  %Deliverble
# Prev Close                   -0.425812     0.280438
# Open                         -0.427702     0.279082
# High                         -0.425891     0.274975
# Low                          -0.431070     0.281765
# Last                         -0.428924     0.277568
# Close                        -0.429132     0.277573
# VWAP                         -0.428697     0.277688
# Volume                        0.921729    -0.363562
# Turnover                      0.811013    -0.271228
# Trades                        0.814693    -0.308742
# Deliverable Volume            1.000000    -0.137384
# %Deliverble                  -0.137384     1.000000

# %%
sns.boxplot(Stock_I['Close'])
# Out:
# C:\Users\Shriprada\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Close'>

# %%
sns.barplot(Stock_I['Close'])
# Out:
# C:\Users\Shriprada\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Close'>

# %%
plt.figure(figsize=(16,8))
plt.title('Close Price History')
plt.plot(I_Close)
plt.xlabel('Date', fontsize = 18)
plt.ylabel('Close Prise', fontsize = 18)
plt.show()

# %%
ma100_I = Stock_I.Close.rolling(100).mean()
ma100_I
# Out:
# Date
# 2012-10-01          NaN
# 2012-10-03          NaN
# 2012-10-04          NaN
# 2012-10-05          NaN
# 2012-10-08          NaN
#                 ...
# 2022-10-10    1480.4870
# 2022-10-11    1479.6330
# 2022-10-12    1479.6485
# 2022-10-13    1479.2960
# 2022-10-14    1479.3545
# Name: Close, Length: 2484, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.plot(Stock_I.Close)
plt.plot(ma100_I, 'r')

# %%
plt.hist(I_Close, bins = 10)
# Out:
# (array([483., 872., 302., 219., 181.,  62., 129., 135.,  81.,  20.]),
#  array([ 526.45 ,  910.395, 1294.34 , 1678.285, 2062.23 , 2446.175,
#         2830.12 , 3214.065, 3598.01 , 3981.955, 4365.9  ]),
#  <BarContainer object of 10 artists>)

# %%
Stock_I['Close'].plot(kind = 'kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
lag_plot(I_Close)
pyplot.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(Stock_I.Close)
plt.plot(Stock_I.Open, 'r')

# %%
sns.heatmap(Stock_I.corr(), cmap = "PuBuGn")
# Out:
# <AxesSubplot:>

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
result = seasonal_decompose(I_Close, model='multiplicative', period = 365)
fig = plt.figure()  
fig = result.plot()  
fig.set_size_inches(16, 9)

# %%
I_cumsum = Stock_I.cumsum()
I_cumsum.plot()
plt.title('Infosys Cumulative Returns')
# Out:
# Text(0.5, 1.0, 'Infosys Cumulative Returns')

# %%
I_cumsums = I_Close.cumsum()
I_cumsums.plot()
plt.title('Infosys Cumulative Returns')
# Out:
# Text(0.5, 1.0, 'Infosys Cumulative Returns')

# %%
Stock_I['Close'].resample(rule='M').mean().plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### EDA ON TATA

# %%
Tata
# Out:
#                 Symbol Series  Prev Close    Open   High     Low    Last  \
# Date
# 2012-10-01  TATAMOTORS     EQ      267.55  268.00  276.2  268.00  274.45
# 2012-10-03  TATAMOTORS     EQ      274.70  275.00  276.0  270.20  273.00
# 2012-10-04  TATAMOTORS     EQ      273.50  275.25  279.0  273.15  273.35
# 2012-10-05  TATAMOTORS     EQ      274.30  276.50  282.5  219.45  281.50
# 2012-10-08  TATAMOTORS     EQ      280.55  281.45  283.7  271.00  271.95
# ...                ...    ...         ...     ...    ...     ...     ...
# 2022-10-10  TATAMOTORS     EQ      412.15  403.40  403.4  393.05  396.55
# 2022-10-11  TATAMOTORS     EQ      395.95  397.00  399.5  391.30  391.75
# 2022-10-12  TATAMOTORS     EQ      393.35  394.55  398.2  391.10  396.75
# 2022-10-13  TATAMOTORS     EQ      396.55  396.55  403.5  394.55  399.00
# 2022-10-14  TATAMOTORS     EQ      399.00  407.00  409.2  395.30  396.25
#
#              Close    VWAP    Volume      Turnover  Trades  \
# Date
# 2012-10-01  274.70  273.08   9420145  2.572465e+14   88596
# 2012-10-03  273.50  273.10   9136919  2.495328e+14   70558
# 2012-10-04  274.30  276.46   7581304  2.095891e+14   72562
# 2012-10-05  280.55  278.70  17095335  4.764485e+14  114300
# 2012-10-08  272.45  277.05   7590848  2.103010e+14   76338
# ...            ...     ...       ...           ...     ...
# 2022-10-10  395.95  396.05  32914630  1.303588e+15  383835
# 2022-10-11  393.35  396.08  14641301  5.799094e+14  187285
# 2022-10-12  396.55  394.96  14287344  5.642950e+14  170299
# 2022-10-13  399.00  398.20  12584114  5.011017e+14  142183
# 2022-10-14  396.25  401.55  12875470  5.170199e+14  135477
#
#             Deliverable Volume  %Deliverble
# Date
# 2012-10-01             4221642       0.4482
# 2012-10-03             3772453       0.4129
# 2012-10-04             3202071       0.4224
# 2012-10-05             6820337       0.3990
# 2012-10-08             2946526       0.3882
# ...                        ...          ...
# 2022-10-10            12262312       0.3725
# 2022-10-11             3677800       0.2512
# 2022-10-12             3002072       0.2101
# 2022-10-13             3624102       0.2880
# 2022-10-14             2634822       0.2046
#
# [2484 rows x 14 columns]

# %%
T_Close = pd.DataFrame(Tata['Close'])
T_Close
# Out:
#              Close
# Date
# 2012-10-01  274.70
# 2012-10-03  273.50
# 2012-10-04  274.30
# 2012-10-05  280.55
# 2012-10-08  272.45
# ...            ...
# 2022-10-10  395.95
# 2022-10-11  393.35
# 2022-10-12  396.55
# 2022-10-13  399.00
# 2022-10-14  396.25
#
# [2484 rows x 1 columns]

# %%
Tata.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  2484.000000  2484.000000  2484.000000  2484.000000  2484.000000
# mean    343.563788   344.194948   349.107709   338.611292   343.605878
# std     130.047720   130.247264   131.374191   128.804555   130.019497
# min      65.300000    66.500000    66.900000    63.500000    65.450000
# 25%     262.625000   262.262500   267.387500   258.812500   262.762500
# 50%     360.300000   361.200000   367.450000   356.350000   361.100000
# 75%     446.137500   446.787500   453.000000   440.487500   446.262500
# max     604.550000   606.650000   612.400000   596.200000   606.000000
#
#              Close         VWAP        Volume      Turnover        Trades  \
# count  2484.000000  2484.000000  2.484000e+03  2.484000e+03  2.484000e+03
# mean    343.615600   343.944118  2.211349e+07  5.771482e+14  1.506466e+05
# std     130.043061   130.057765  3.025764e+07  7.392701e+14  1.295157e+05
# min      65.300000    65.500000  3.008140e+05  9.824843e+12  3.702000e+03
# 25%     262.625000   262.947500  6.206958e+06  2.317032e+14  7.928425e+04
# 50%     360.425000   362.075000  1.023826e+07  3.443915e+14  1.108940e+05
# 75%     446.137500   446.387500  2.524180e+07  6.224327e+14  1.732385e+05
# max     604.550000   604.730000  3.905778e+08  9.853175e+15  1.517162e+06
#
#        Deliverable Volume  %Deliverble
# count        2.484000e+03  2484.000000
# mean         5.014342e+06     0.359280
# std          4.426799e+06     0.169910
# min          6.229600e+04     0.038500
# 25%          2.602443e+06     0.202600
# 50%          3.797299e+06     0.369450
# 75%          5.874090e+06     0.499475
# max          7.333848e+07     0.847900

# %%
Tata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2484 entries, 2012-10-01 to 2022-10-14
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Symbol              2484 non-null   object
#  1   Series              2484 non-null   object
#  2   Prev Close          2484 non-null   float64
#  3   Open                2484 non-null   float64
#  4   High                2484 non-null   float64
#  5   Low                 2484 non-null   float64
#  6   Last                2484 non-null   float64
#  7   Close               2484 non-null   float64
#  8   VWAP                2484 non-null   float64
#  9   Volume              2484 non-null   int64
#  10  Turnover            2484 non-null   float64
#  11  Trades              2484 non-null   int64
#  12  Deliverable Volume  2484 non-null   int64
#  13  %Deliverble         2484 non-null   float64
# dtypes: float64(9), int64(3), object(2)
# memory usage: 291.1+ KB

# %%
Tata.shape
# Out:
# (2484, 14)

# %%
Tata.reset_index(inplace = True)

Tata['Date'] = pd.to_datetime(Tata['Date'])

Tata.set_index('Date', inplace = True)
Tata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2484 entries, 2012-10-01 to 2022-10-14
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Symbol              2484 non-null   object
#  1   Series              2484 non-null   object
#  2   Prev Close          2484 non-null   float64
#  3   Open                2484 non-null   float64
#  4   High                2484 non-null   float64
#  5   Low                 2484 non-null   float64
#  6   Last                2484 non-null   float64
#  7   Close               2484 non-null   float64
#  8   VWAP                2484 non-null   float64
#  9   Volume              2484 non-null   int64
#  10  Turnover            2484 non-null   float64
#  11  Trades              2484 non-null   int64
#  12  Deliverable Volume  2484 non-null   int64
#  13  %Deliverble         2484 non-null   float64
# dtypes: float64(9), int64(3), object(2)
# memory usage: 291.1+ KB

# %%
Tata.corr()
# Out:
#                     Prev Close      Open      High       Low      Last  \
# Prev Close            1.000000  0.999446  0.998711  0.998578  0.997863
# Open                  0.999446  1.000000  0.999286  0.999223  0.998498
# High                  0.998711  0.999286  1.000000  0.999161  0.999461
# Low                   0.998578  0.999223  0.999161  1.000000  0.999297
# Last                  0.997863  0.998498  0.999461  0.999297  1.000000
# Close                 0.997875  0.998516  0.999480  0.999336  0.999969
# VWAP                  0.998624  0.999232  0.999781  0.999669  0.999708
# Volume               -0.472832 -0.470017 -0.459767 -0.474435 -0.464975
# Turnover             -0.107062 -0.102360 -0.089202 -0.108481 -0.096422
# Trades               -0.195127 -0.192760 -0.180525 -0.201675 -0.189358
# Deliverable Volume   -0.291693 -0.288698 -0.278223 -0.295335 -0.285259
# %Deliverble           0.605977  0.604940  0.600637  0.605653  0.601483
#
#                        Close      VWAP    Volume  Turnover    Trades  \
# Prev Close          0.997875  0.998624 -0.472832 -0.107062 -0.195127
# Open                0.998516  0.999232 -0.470017 -0.102360 -0.192760
# High                0.999480  0.999781 -0.459767 -0.089202 -0.180525
# Low                 0.999336  0.999669 -0.474435 -0.108481 -0.201675
# Last                0.999969  0.999708 -0.464975 -0.096422 -0.189358
# Close               1.000000  0.999747 -0.465194 -0.096748 -0.189712
# VWAP                0.999747  1.000000 -0.466315 -0.097583 -0.190110
# Volume             -0.465194 -0.466315  1.000000  0.838046  0.853150
# Turnover           -0.096748 -0.097583  0.838046  1.000000  0.942806
# Trades             -0.189712 -0.190110  0.853150  0.942806  1.000000
# Deliverable Volume -0.285369 -0.285731  0.742443  0.705917  0.737518
# %Deliverble         0.601514  0.602349 -0.569511 -0.408235 -0.459459
#
#                     Deliverable Volume  %Deliverble
# Prev Close                   -0.291693     0.605977
# Open                         -0.288698     0.604940
# High                         -0.278223     0.600637
# Low                          -0.295335     0.605653
# Last                         -0.285259     0.601483
# Close                        -0.285369     0.601514
# VWAP                         -0.285731     0.602349
# Volume                        0.742443    -0.569511
# Turnover                      0.705917    -0.408235
# Trades                        0.737518    -0.459459
# Deliverable Volume            1.000000    -0.188467
# %Deliverble                  -0.188467     1.000000

# %%
Tata.isnull().sum()
# Out:
# Symbol                0
# Series                0
# Prev Close            0
# Open                  0
# High                  0
# Low                   0
# Last                  0
# Close                 0
# VWAP                  0
# Volume                0
# Turnover              0
# Trades                0
# Deliverable Volume    0
# %Deliverble           0
# dtype: int64

# %%
sns.boxplot(Tata['Close'])
# Out:
# C:\Users\Shriprada\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Close'>

# %%
sns.barplot(Tata['Close'])
# Out:
# C:\Users\Shriprada\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Close'>

# %%
plt.figure(figsize=(16,8))
plt.title('Close Price History')
plt.plot(T_Close)
plt.xlabel('Date', fontsize = 18)
plt.ylabel('Close Prise', fontsize = 18)
plt.show()

# %%
ma100_T = Tata.Close.rolling(100).mean()
ma100_T
# Out:
# Date
# 2012-10-01        NaN
# 2012-10-03        NaN
# 2012-10-04        NaN
# 2012-10-05        NaN
# 2012-10-08        NaN
#                ...
# 2022-10-10    435.441
# 2022-10-11    435.223
# 2022-10-12    435.202
# 2022-10-13    435.012
# 2022-10-14    434.760
# Name: Close, Length: 2484, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.plot(Tata.Close)
plt.plot(ma100_T, 'r')

# %%
plt.hist(T_Close, bins =10)
# Out:
# (array([119., 248., 193., 154., 403., 298., 422., 341., 240.,  66.]),
#  array([ 65.3  , 119.225, 173.15 , 227.075, 281.   , 334.925, 388.85 ,
#         442.775, 496.7  , 550.625, 604.55 ]),
#  <BarContainer object of 10 artists>)

# %%
Tata['Close'].plot(kind = 'kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
lag_plot(T_Close)
pyplot.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(Tata.Close)
plt.plot(Tata.Open, 'r')

# %%
sns.heatmap(Tata.corr(), cmap = "GnBu_r")
# Out:
# <AxesSubplot:>

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
result = seasonal_decompose(T_Close, model='multiplicative', period = 365)
fig = plt.figure()  
fig = result.plot()  
fig.set_size_inches(16, 9)

# %%
T_cumsum = T_Close.cumsum()
T_cumsum.plot()
plt.title('Tata Cumulative Returns')
# Out:
# Text(0.5, 1.0, 'Tata Cumulative Returns')

# %%
Tata['Close'].resample(rule='M').mean().plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### EDA ON RELIANCE

# %%
Reliance
# Out:
#               Symbol Series  Prev Close     Open     High      Low     Last  \
# Date
# 2012-10-01  RELIANCE     EQ      837.20   840.00   842.30   829.25   834.10
# 2012-10-03  RELIANCE     EQ      833.50   834.45   853.45   834.25   847.45
# 2012-10-04  RELIANCE     EQ      846.10   850.55   858.90   849.10   852.00
# 2012-10-05  RELIANCE     EQ      852.90   859.90   862.00   682.35   859.55
# 2012-10-08  RELIANCE     EQ      857.80   854.55   854.55   816.25   817.00
# ...              ...    ...         ...      ...      ...      ...      ...
# 2022-10-10  RELIANCE     EQ     2432.35  2405.00  2417.60  2388.00  2407.00
# 2022-10-11  RELIANCE     EQ     2405.80  2414.00  2414.00  2351.10  2353.55
# 2022-10-12  RELIANCE     EQ     2357.90  2352.00  2381.70  2343.10  2377.00
# 2022-10-13  RELIANCE     EQ     2375.25  2371.40  2394.00  2360.10  2381.00
# 2022-10-14  RELIANCE     EQ     2382.80  2415.00  2416.35  2369.10  2371.75
#
#               Close     VWAP   Volume      Turnover  Trades  \
# Date
# 2012-10-01   833.50   834.99  1991469  1.662860e+14   49735
# 2012-10-03   846.10   845.93  5006639  4.235262e+14  110536
# 2012-10-04   852.90   853.87  2886232  2.464463e+14   70943
# 2012-10-05   857.80   846.95  3592138  3.042348e+14   60282
# 2012-10-08   819.40   828.39  4775793  3.956202e+14   96671
# ...             ...      ...      ...           ...     ...
# 2022-10-10  2405.80  2403.20  2921076  7.019928e+14  136725
# 2022-10-11  2357.90  2377.84  4252803  1.011249e+15  197213
# 2022-10-12  2375.25  2368.06  3422992  8.105861e+14  158484
# 2022-10-13  2382.80  2379.51  3382098  8.047737e+14  163282
# 2022-10-14  2370.70  2392.60  4202459  1.005482e+15  178804
#
#             Deliverable Volume  %Deliverble
# Date
# 2012-10-01              972193       0.4882
# 2012-10-03             2908157       0.5809
# 2012-10-04             1522797       0.5276
# 2012-10-05             1052935       0.2931
# 2012-10-08             2860535       0.5990
# ...                        ...          ...
# 2022-10-10             1453561       0.4976
# 2022-10-11             2480007       0.5831
# 2022-10-12             1914563       0.5593
# 2022-10-13             1976668       0.5845
# 2022-10-14             2676992       0.6370
#
# [2484 rows x 14 columns]

# %%
R_Close = pd.DataFrame(Reliance['Close'])
R_Close
# Out:
#               Close
# Date
# 2012-10-01   833.50
# 2012-10-03   846.10
# 2012-10-04   852.90
# 2012-10-05   857.80
# 2012-10-08   819.40
# ...             ...
# 2022-10-10  2405.80
# 2022-10-11  2357.90
# 2022-10-12  2375.25
# 2022-10-13  2382.80
# 2022-10-14  2370.70
#
# [2484 rows x 1 columns]

# %%
Reliance.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  2484.000000  2484.000000  2484.000000  2484.000000  2484.000000
# mean   1337.456240  1339.125543  1354.283233  1323.339956  1337.962359
# std     560.627401   561.488811   567.868295   554.738031   560.929127
# min     765.350000   766.000000   773.700000   682.350000   763.200000
# 25%     920.400000   921.950000   931.187500   913.000000   920.412500
# 50%    1062.825000  1063.925000  1075.450000  1048.675000  1062.550000
# 75%    1570.237500  1572.000000  1584.237500  1556.237500  1573.462500
# max    2819.850000  2856.150000  2856.150000  2786.100000  2810.000000
#
#              Close         VWAP        Volume      Turnover        Trades  \
# count  2484.000000  2484.000000  2.484000e+03  2.484000e+03  2.484000e+03
# mean   1338.073591  1339.023442  6.784734e+06  1.020033e+15  1.661596e+05
# std     560.920560   561.266770  6.285074e+06  1.197476e+15  1.357436e+05
# min     765.350000   766.600000  1.110540e+05  9.037442e+12  3.338000e+03
# 25%     920.700000   922.022500  3.027037e+06  2.903924e+14  7.841225e+04
# 50%    1063.125000  1061.135000  4.861845e+06  5.852769e+14  1.219845e+05
# 75%    1571.587500  1569.105000  8.119365e+06  1.319023e+15  2.124328e+05
# max    2819.850000  2823.910000  6.523089e+07  1.473434e+16  1.428490e+06
#
#        Deliverable Volume  %Deliverble
# count        2.484000e+03  2484.000000
# mean         3.009785e+06     0.496214
# std          2.152832e+06     0.120963
# min          3.174100e+04     0.114800
# 25%          1.636553e+06     0.418050
# 50%          2.429273e+06     0.508100
# 75%          3.671275e+06     0.581125
# max          1.973411e+07     0.832700

# %%
Reliance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2484 entries, 2012-10-01 to 2022-10-14
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Symbol              2484 non-null   object
#  1   Series              2484 non-null   object
#  2   Prev Close          2484 non-null   float64
#  3   Open                2484 non-null   float64
#  4   High                2484 non-null   float64
#  5   Low                 2484 non-null   float64
#  6   Last                2484 non-null   float64
#  7   Close               2484 non-null   float64
#  8   VWAP                2484 non-null   float64
#  9   Volume              2484 non-null   int64
#  10  Turnover            2484 non-null   float64
#  11  Trades              2484 non-null   int64
#  12  Deliverable Volume  2484 non-null   int64
#  13  %Deliverble         2484 non-null   float64
# dtypes: float64(9), int64(3), object(2)
# memory usage: 291.1+ KB

# %%
Reliance.shape
# Out:
# (2484, 14)

# %%
Reliance.isnull().sum()
# Out:
# Symbol                0
# Series                0
# Prev Close            0
# Open                  0
# High                  0
# Low                   0
# Last                  0
# Close                 0
# VWAP                  0
# Volume                0
# Turnover              0
# Trades                0
# Deliverable Volume    0
# %Deliverble           0
# dtype: int64

# %%
Reliance.reset_index(inplace = True)

Reliance['Date'] = pd.to_datetime(Reliance['Date'])

Reliance.set_index('Date', inplace = True)
Reliance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2484 entries, 2012-10-01 to 2022-10-14
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Symbol              2484 non-null   object
#  1   Series              2484 non-null   object
#  2   Prev Close          2484 non-null   float64
#  3   Open                2484 non-null   float64
#  4   High                2484 non-null   float64
#  5   Low                 2484 non-null   float64
#  6   Last                2484 non-null   float64
#  7   Close               2484 non-null   float64
#  8   VWAP                2484 non-null   float64
#  9   Volume              2484 non-null   int64
#  10  Turnover            2484 non-null   float64
#  11  Trades              2484 non-null   int64
#  12  Deliverable Volume  2484 non-null   int64
#  13  %Deliverble         2484 non-null   float64
# dtypes: float64(9), int64(3), object(2)
# memory usage: 291.1+ KB

# %%
sns.boxplot(Reliance['Close'])
# Out:
# C:\Users\Shriprada\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Close'>

# %%
sns.barplot(Reliance['Close'])
# Out:
# C:\Users\Shriprada\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Close'>

# %%
plt.figure(figsize=(16,8))
plt.title('Close Price History')
plt.plot(R_Close)
plt.xlabel('Date', fontsize = 18)
plt.ylabel('Close Prise', fontsize = 18)
plt.show()

# %%
ma100_R = Reliance.Close.rolling(100).mean()
ma100_R
# Out:
# Date
# 2012-10-01          NaN
# 2012-10-03          NaN
# 2012-10-04          NaN
# 2012-10-05          NaN
# 2012-10-08          NaN
#                 ...
# 2022-10-10    2541.0080
# 2022-10-11    2539.2035
# 2022-10-12    2538.1575
# 2022-10-13    2535.7410
# 2022-10-14    2533.3790
# Name: Close, Length: 2484, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.plot(Reliance.Close)
plt.plot(ma100_R, 'r')

# %%
plt.hist(R_Close, bins =10)
# Out:
# (array([862., 547., 290., 180.,  36., 104., 147., 119., 141.,  58.]),
#  array([ 765.35,  970.8 , 1176.25, 1381.7 , 1587.15, 1792.6 , 1998.05,
#         2203.5 , 2408.95, 2614.4 , 2819.85]),
#  <BarContainer object of 10 artists>)

# %%
Reliance['Close'].plot(kind = 'kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
lag_plot(R_Close)
pyplot.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(Reliance.Close)
plt.plot(Reliance.Open, 'r')

# %%
sns.heatmap(Reliance.corr(), cmap = "GnBu_r")
# Out:
# <AxesSubplot:>

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
result = seasonal_decompose(R_Close, model='multiplicative', period = 30)
fig = plt.figure()  
fig = result.plot()  
fig.set_size_inches(16, 9)

# %%
R_cumsum = R_Close.cumsum()
R_cumsum.plot()
plt.title('Wipro Cumulative Returns')
# Out:
# Text(0.5, 1.0, 'Wipro Cumulative Returns')

# %%
Reliance['Close'].resample(rule='M').mean().plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Concating Datas

# %%
df = pd.DataFrame({'reliance':Reliance['Close'], 'infosys': Stock_I['Close'], 'tata': Tata['Close'], 'wipro': stock_W['Close']})
df
# Out:
#             reliance  infosys    tata   wipro
# Date
# 2012-10-01    833.50  2609.65  274.70  382.70
# 2012-10-03    846.10  2578.25  273.50  380.25
# 2012-10-04    852.90  2575.65  274.30  382.90
# 2012-10-05    857.80  2526.85  280.55  373.25
# 2012-10-08    819.40  2488.20  272.45  365.40
# ...              ...      ...     ...     ...
# 2022-10-10   2405.80  1462.65  395.95  411.30
# 2022-10-11   2357.90  1423.80  393.35  404.40
# 2022-10-12   2375.25  1428.70  396.55  407.95
# 2022-10-13   2382.80  1419.90  399.00  379.10
# 2022-10-14   2370.70  1474.25  396.25  377.30
#
# [2484 rows x 4 columns]

# %%
df.isnull().sum()
# Out:
# reliance    0
# infosys     0
# tata        0
# wipro       0
# dtype: int64

# %%
plt.hist(df)
# Out:
# (array([[   0.,  645., 1021.,  248.,  261.,  274.,   35.,    0.,    0.,
#             0.],
#         [   0.,  517.,  901.,  345.,  155.,  164.,  127.,  151.,  102.,
#            22.],
#         [2175.,  309.,    0.,    0.,    0.,    0.,    0.,    0.,    0.,
#             0.],
#         [1516.,  968.,    0.,    0.,    0.,    0.,    0.,    0.,    0.,
#             0.]]),
#  array([  65.3 ,  495.36,  925.42, 1355.48, 1785.54, 2215.6 , 2645.66,
#         3075.72, 3505.78, 3935.84, 4365.9 ]),
#  <a list of 4 BarContainer objects>)

# %%
df_cumsum = df.cumsum()
df_cumsum.plot()
plt.title('Cumulative Returns')
# Out:
# Text(0.5, 1.0, 'Cumulative Returns')

# %%
sns.heatmap(df.corr(), cmap = 'RdYlBu')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Modelling

# %%
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
plot_pacf(close_W.squeeze(), lags = 20)
plot_acf(close_W.squeeze(), lags = 20)
# Out:
# C:\Users\Shriprada\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# ## Splitting Data into Train and Test

# %%
split_point = len(close_W) - 365
train_W = close_W[0:split_point]
test_W = close_W[split_point:]

# %%
train_W.shape
# Out:
# (2119, 1)

# %%
test_W.shape
# Out:
# (365, 1)

# %% [markdown]
# ## Naive Bayes

# %%
sp =len(stock_W) - 30
train_W1= W[0:sp]
test_W1 = W[sp:]

# %%
y_hat = test_W.copy() 
y_hat['naive'] = test_W 
plt.figure(figsize=(12,8)) 
plt.plot(train_W.index, train_W['Close'], label='Train') 
plt.plot(test_W.index,test_W['Close'], label='Valid') 
#plt.plot(y_hat.index,y_hat['naive'], label='Naive Forecast') 
plt.legend(loc='best') 
plt.title("Naive Forecast") 
plt.show()

# %%
y_hat = test_W.copy() 
y_hat['naive'] = test_W 
plt.figure(figsize=(12,8)) 
plt.plot(train_W.index, train_W['Close'], label='Train') 
plt.plot(test_W.index,test_W['Close'], label='Valid') 
plt.plot(y_hat.index,y_hat['naive'], label='Naive Forecast') 
plt.legend(loc='best') 
plt.title("Naive Forecast") 
plt.show()

# %%
from sklearn.metrics import mean_squared_error 
from math import sqrt 
rms = sqrt(mean_squared_error(test_W.Close, y_hat.naive)) 
print(rms)
# Out:
# 0.0

# %%
colnames = W.columns

# %%
#2

x_train = train_W1[colnames[0:5]].values
y_train = train_W1[colnames[5]].values
x_test = test_W1[colnames[0:5]].values
y_test = test_W1[colnames[5]].values

# %%
def norm_func(i):
    x = (i-i.min())/(i.max() - i.min())
    return (x)

# %%
x_train = norm_func(x_train)
x_test = norm_func(x_test)

# %%
from sklearn.naive_bayes import MultinomialNB as MB

M_model = MB()
train_pred_multi = M_model.fit(x_train, y_train.astype('int')).predict(x_train)
test_pred_multi = M_model.fit(x_test, y_test.astype('int')).predict(x_test)

# %%
train_acc_multi = np.mean(train_pred_multi == y_train)
train_acc_multi
# Out:
# 0.00040749796251018743

# %%
test_acc_multi = np.mean(test_pred_multi== y_test)
test_acc_multi
# Out:
# 0.0

# %%
from sklearn.naive_bayes import GaussianNB as GB
G_model=GB()
train_pred_gau=G_model.fit(x_train,y_train.astype('int')).predict(x_train)
test_pred_gau=G_model.fit(x_test,y_test.astype('int')).predict(x_test)

# %%
train_acc_gau = np.mean(train_pred_gau == y_train)
train_acc_gau
# Out:
# 0.03993480032599837

# %%
test_acc_gau = np.mean(test_pred_gau == y_test)
test_acc_gau
# Out:
# 0.03333333333333333

# %% [markdown]
# ## ARIMA

# %%
train_data, test_data = stock_W[0:int(len(stock_W)*0.6)], stock_W[int(len(stock_W)*0.6):]
plt.figure(figsize=(12,7))
plt.title('Wipro Prices')
plt.xlabel('Dates')
plt.ylabel('Close')
plt.plot(stock_W['Close'], 'blue', label='Training Data')
plt.plot(test_data['Close'], 'green', label='Testing Data')
plt.legend()

# %%
def wipro_val(y_true, y_pred):
    return np.mean((np.abs(y_pred - y_true) * 200/ (np.abs(y_pred) + np.abs(y_true))))

# %% [markdown]
# ### Augumented Dickey - Fuller test
#
# #### Null hypothesis - The series is stationary
# #### Alternate hypothesis - The series is not stationary

# %%
from statsmodels.tsa.stattools import adfuller
result = adfuller(close_W['Close'])
print('ADF Statistics: %f' %result[0])
print('p-value:%f' %result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' %(key,value))
# Out:
# ADF Statistics: -1.772210
# p-value:0.394343
# Critical Values:
# 	1%: -3.433
# 	5%: -2.863
# 	10%: -2.567

# %% [markdown]
# ### Here we see that p - value is more than 0.05. Hence our null hypothesis will be rejected . Thus this series is non-stationary.

# %%
close_W.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### Finding d - parameter

# %%
plt.rcParams.update({'figure.figsize':(20,15),'figure.dpi':120})

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3)
ax1.plot(close_W.Close)
ax1.set_title('Original Series')
ax1.axes.xaxis.set_visible(False)

#1st Differencing
ax2.plot(close_W.Close.diff())
ax2.set_title('1st Order Differencing')
ax2.axes.xaxis.set_visible(False)

#2nd Differencing
ax3.plot(close_W.Close.diff().diff())
ax3.set_title('2nd Order Differencing')
ax3.axes.xaxis.set_visible(False)

plt.show()

# %% [markdown]
# #### Since comparitively, second order differencing has lesser noice than first order, we consider d = 2.

# %%
from statsmodels.graphics.tsaplots import plot_acf
fig, (ax1, ax2, ax3) = plt.subplots(3)
plot_acf(close_W.Close, ax=ax1)
plot_acf(close_W.Close.diff().dropna(), ax=ax2)
plot_acf(close_W.Close.diff().diff().dropna(), ax=ax3)

# %%
from statsmodels.graphics.tsaplots import plot_pacf
plt.figure(figsize = (20,15))
plot_pacf(close_W.Close.diff().diff().dropna())
# Out:
# C:\Users\Shriprada\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# #### p = 1

# %%
plot_acf(close_W.Close.diff().diff().dropna())

# %% [markdown]
# #### q= 1

# %%
from statsmodels.tsa.arima.model import ARIMA
import statsmodels.api as smapi
model = smapi.tsa.arima.ARIMA(close_W.Close, order = (1,2,1))
model_fit = model.fit()
model_fit.summary()
# Out:
# C:\Users\Shriprada\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Shriprada\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Shriprada\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 2484
# Model:                 ARIMA(1, 2, 1)   Log Likelihood               -9008.704
# Date:                Tue, 25 Oct 2022   AIC                          18023.407
# Time:                        16:16:56   BIC                          18040.858
# Sample:                             0   HQIC                         18029.745
#                                - 2484
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0337      0.022      1.502      0.133      -0.010       0.078
# ma.L1         -0.9998      0.008   -123.807      0.000      -1.016      -0.984
# sigma2        82.9626      0.585    141.920      0.000      81.817      84.108
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):           9397844.79
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.90   Skew:                           -10.65
# Prob(H) (two-sided):                  0.14   Kurtosis:                       303.70
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
train_w = train_data['Close'].values
test_w = test_data['Close'].values

history = [x for x in train_w]
print(type(history))
predictions = list()
for t in range(len(test_w)):
    model = ARIMA(history, order=(1,2,1))
    model_fit = model.fit()
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test_w[t]
    history.append(obs)
    #print('predicted=%f, expected=%f' % (yhat, obs))
# Out:
# <class 'list'>

# %%
error = mean_squared_error(test_w, predictions)
print('Testing Mean Squared Error: %.3f' % error)
error2 = wipro_val(test_w, predictions)
print('Symmetric mean absolute percentage error: %.3f' % error2)
# Out:
# Testing Mean Squared Error: 62.324
# Symmetric mean absolute percentage error: 1.343

# %%
plt.figure(figsize=(12,7))
plt.plot(close_W['Close'], 'green', color='blue', label='Training Data')
plt.plot(test_data.index, predictions, color='green', marker='o', linestyle='dashed', 
         label='Predicted Price')
plt.plot(test_data.index, test_data['Close'], color='red', label='Actual Price')
plt.title('Close price Prediction')
plt.xlabel('Dates')
plt.ylabel('Prices')
plt.legend()
# Out:
# C:\Users\Shriprada\AppData\Local\Temp\ipykernel_22804\3898090080.py:2: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "green" (-> color=(0.0, 0.5019607843137255, 0.0, 1.0)). The keyword argument will take precedence.
#   plt.plot(close_W['Close'], 'green', color='blue', label='Training Data')

# %%
pred_new = pd.DataFrame(model_fit.predict(start=0,end=6)[1:], columns = ['Prediction'])

# %%
pred_new = pred_new.drop([0, 1])
pred_new.reset_index(inplace = True)
#pred_new.drop(columns =['index'])

# %%
start_date_n = date(2022, 10, 15)
end_date_n = date(2022,10,21)

Wipro_n = get_history(symbol = 'WIPRO', start = start_date_n, end = end_date_n)
print(Wipro_n)
# Out:
#            Symbol Series  Prev Close   Open    High     Low   Last   Close  \
# Date
# 2022-10-17  WIPRO     EQ      377.30  377.3  378.95  372.40  375.9  375.10
# 2022-10-18  WIPRO     EQ      375.10  383.7  384.25  378.40  379.4  379.30
# 2022-10-19  WIPRO     EQ      379.30  381.2  381.20  377.05  378.4  378.05
# 2022-10-20  WIPRO     EQ      378.05  377.0  382.60  376.00  381.4  381.50
# 2022-10-21  WIPRO     EQ      381.50  382.5  383.30  380.20  382.7  382.55
#
#               VWAP    Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2022-10-17  375.44   8454769  3.174249e+14  150604             3275719
# 2022-10-18  380.41  11164240  4.246977e+14  162138             5532754
# 2022-10-19  378.88   5099139  1.931949e+14   95814             2222146
# 2022-10-20  380.74   5934407  2.259489e+14   96112             2684614
# 2022-10-21  382.06   4465770  1.706187e+14   68431             1993440
#
#             %Deliverble
# Date
# 2022-10-17       0.3874
# 2022-10-18       0.4956
# 2022-10-19       0.4358
# 2022-10-20       0.4524
# 2022-10-21       0.5674

# %%
w_n = pd.DataFrame(Wipro_n)

# %%
w_nc = pd.DataFrame(w_n['Close'])
w_nc.reset_index(inplace=True)

# %%
p_n = pd.concat([pred_new, w_nc], axis = 1)
p_n.drop(columns = ['index'])
# Out:
#    Prediction        Date   Close
# 0  383.101214  2022-10-17  375.10
# 1  369.828013  2022-10-18  379.30
# 2  360.950628  2022-10-19  378.05
# 3  364.246693  2022-10-20  381.50
# 4         NaN  2022-10-21  382.55

# %%
p_n.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## LSTM

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
close_w = close_W
close_w
# Out:
#              Close
# Date
# 2012-10-01  382.70
# 2012-10-03  380.25
# 2012-10-04  382.90
# 2012-10-05  373.25
# 2012-10-08  365.40
# ...            ...
# 2022-10-10  411.30
# 2022-10-11  404.40
# 2022-10-12  407.95
# 2022-10-13  379.10
# 2022-10-14  377.30
#
# [2484 rows x 1 columns]

# %%
train_w = close_w.iloc[:2300]
test_w = close_w.iloc[2300:]

# %%
test_w = test_w[0:184]

# %%
test_w.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 184 entries, 2022-01-18 to 2022-10-14
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   184 non-null    float64
# dtypes: float64(1)
# memory usage: 2.9 KB

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(train_w)
# Out:
# MinMaxScaler()

# %%
scaler_train = scaler.transform(train_w)
scaler_test = scaler.transform(test_w)

# %%
from keras.preprocessing.sequence import TimeseriesGenerator

# %%
len(scaler_train)
# Out:
# 2300

# %%
from keras.models import Sequential
from keras.layers import Dense,LSTM

# %%
n_input = 184
n_feature = 1

train_generator_w = TimeseriesGenerator(scaler_train, scaler_train, length = n_input, batch_size = 1)

# %%
model = Sequential()

model.add(LSTM(128, activation = 'relu', input_shape=(n_input, n_feature), return_sequences = True))
model.add(LSTM(128, activation = 'relu', input_shape=(n_input, n_feature), return_sequences = True))
model.add(LSTM(128, activation = 'relu', input_shape=(n_input, n_feature), return_sequences = False))
model.add(Dense(1))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 184, 128)          66560
#
#  lstm_1 (LSTM)               (None, 184, 128)          131584
#
#  lstm_2 (LSTM)               (None, 128)               131584
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 329,857
# Trainable params: 329,857
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam', loss= 'mean_squared_error')
model.fit_generator(train_generator_w, epochs = 5)
# Out:
# C:\Users\Shriprada\AppData\Local\Temp\ipykernel_22804\1678058827.py:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(train_generator_w, epochs = 5)
# Epoch 1/5
# 2116/2116 [==============================] - 597s 272ms/step - loss: 0.0049
# Epoch 2/5
# 2116/2116 [==============================] - 565s 267ms/step - loss: 0.0017
# Epoch 3/5
# 2116/2116 [==============================] - 561s 265ms/step - loss: 0.0012
# Epoch 4/5
# 2116/2116 [==============================] - 561s 265ms/step - loss: 7.8321e-04
# Epoch 5/5
# 2116/2116 [==============================] - 414s 196ms/step - loss: 6.8513e-04

# %%
losses_lstm = model.history.history['loss']
plt.figure(figsize = (12,4))
plt.xticks(np.arange(0,21,1))
plt.plot(range(len(losses_lstm)), losses_lstm)

# %%
lstm_predictions_scaled = list()

batch = scaler_train[-n_input:]
current_batch = batch.reshape((1, n_input, n_feature))

for i in range(len(test_w)):   
    lstm_pred = model.predict(current_batch)[0]
    lstm_predictions_scaled.append(lstm_pred) 
    current_batch = np.append(current_batch[:,1:,:],[[lstm_pred]],axis=1)
# Out:
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 221ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 40ms/step

# %%
lstm_predictions_scaled
# Out:
# [array([0.8553282], dtype=float32),
#  array([0.84494334], dtype=float32),
#  array([0.8373882], dtype=float32),
#  array([0.8309348], dtype=float32),
#  array([0.82501394], dtype=float32),
#  array([0.81945354], dtype=float32),
#  array([0.8141665], dtype=float32),
#  array([0.80909747], dtype=float32),
#  array([0.804216], dtype=float32),
#  array([0.7995086], dtype=float32),
#  array([0.7949717], dtype=float32),
#  array([0.79060626], dtype=float32),
#  array([0.78641504], dtype=float32),
#  array([0.78239954], dtype=float32),
#  array([0.77855974], dtype=float32),
#  array([0.77489376], dtype=float32),
#  array([0.77139777], dtype=float32),
#  array([0.768066], dtype=float32),
#  array([0.76489204], dtype=float32),
#  array([0.7618683], dtype=float32),
#  array([0.75898725], dtype=float32),
#  array([0.75624084], dtype=float32),
#  array([0.7536214], dtype=float32),
#  array([0.7511217], dtype=float32),
#  array([0.7487349], dtype=float32),
#  array([0.7464544], dtype=float32),
#  array([0.74427426], dtype=float32),
#  array([0.7421891], dtype=float32),
#  array([0.74019384], dtype=float32),
#  array([0.73828375], dtype=float32),
#  array([0.7364543], dtype=float32),
#  array([0.7347017], dtype=float32),
#  array([0.73302215], dtype=float32),
#  array([0.731412], dtype=float32),
#  array([0.7298681], dtype=float32),
#  array([0.7283871], dtype=float32),
#  array([0.72696644], dtype=float32),
#  array([0.7256031], dtype=float32),
#  array([0.7242945], dtype=float32),
#  array([0.7230382], dtype=float32),
#  array([0.72183186], dtype=float32),
#  array([0.72067326], dtype=float32),
#  array([0.71956027], dtype=float32),
#  array([0.71849084], dtype=float32),
#  array([0.7174634], dtype=float32),
#  array([0.71647567], dtype=float32),
#  array([0.7155263], dtype=float32),
#  array([0.7146135], dtype=float32),
#  array([0.71373576], dtype=float32),
#  array([0.71289164], dtype=float32),
#  array([0.7120797], dtype=float32),
#  array([0.7112985], dtype=float32),
#  array([0.7105469], dtype=float32),
#  array([0.7098238], dtype=float32),
#  array([0.70912784], dtype=float32),
#  array([0.708458], dtype=float32),
#  array([0.7078132], dtype=float32),
#  array([0.7071925], dtype=float32),
#  array([0.7065947], dtype=float32),
#  array([0.7060191], dtype=float32),
#  array([0.70546484], dtype=float32),
#  array([0.70493096], dtype=float32),
#  array([0.7044168], dtype=float32),
#  array([0.7039215], dtype=float32),
#  array([0.7034443], dtype=float32),
#  array([0.7029847], dtype=float32),
#  array([0.70254177], dtype=float32),
#  array([0.702115], dtype=float32),
#  array([0.7017038], dtype=float32),
#  array([0.7013074], dtype=float32),
#  array([0.7009254], dtype=float32),
#  array([0.7005572], dtype=float32),
#  array([0.7002023], dtype=float32),
#  array([0.6998602], dtype=float32),
#  array([0.6995305], dtype=float32),
#  array([0.69921255], dtype=float32),
#  array([0.6989061], dtype=float32),
#  array([0.6986106], dtype=float32),
#  array([0.6983256], dtype=float32),
#  array([0.69805086], dtype=float32),
#  array([0.6977859], dtype=float32),
#  array([0.69753045], dtype=float32),
#  array([0.6972839], dtype=float32),
#  array([0.6970462], dtype=float32),
#  array([0.69681704], dtype=float32),
#  array([0.69659597], dtype=float32),
#  array([0.69638276], dtype=float32),
#  array([0.6961772], dtype=float32),
#  array([0.6959789], dtype=float32),
#  array([0.6957875], dtype=float32),
#  array([0.69560295], dtype=float32),
#  array([0.69542474], dtype=float32),
#  array([0.695253], dtype=float32),
#  array([0.69508725], dtype=float32),
#  array([0.6949273], dtype=float32),
#  array([0.69477296], dtype=float32),
#  array([0.69462407], dtype=float32),
#  array([0.6944805], dtype=float32),
#  array([0.69434184], dtype=float32),
#  array([0.6942081], dtype=float32),
#  array([0.69407904], dtype=float32),
#  array([0.6939544], dtype=float32),
#  array([0.69383425], dtype=float32),
#  array([0.69371825], dtype=float32),
#  array([0.6936063], dtype=float32),
#  array([0.6934983], dtype=float32),
#  array([0.69339406], dtype=float32),
#  array([0.6932935], dtype=float32),
#  array([0.6931965], dtype=float32),
#  array([0.69310284], dtype=float32),
#  array([0.6930124], dtype=float32),
#  array([0.69292516], dtype=float32),
#  array([0.692841], dtype=float32),
#  array([0.69275963], dtype=float32),
#  array([0.69268113], dtype=float32),
#  array([0.6926053], dtype=float32),
#  array([0.6925322], dtype=float32),
#  array([0.69246167], dtype=float32),
#  array([0.6923935], dtype=float32),
#  array([0.69232786], dtype=float32),
#  array([0.69226444], dtype=float32),
#  array([0.6922031], dtype=float32),
#  array([0.6921439], dtype=float32),
#  array([0.69208694], dtype=float32),
#  array([0.69203186], dtype=float32),
#  array([0.69197875], dtype=float32),
#  array([0.6919274], dtype=float32),
#  array([0.69187784], dtype=float32),
#  array([0.69183], dtype=float32),
#  array([0.6917837], dtype=float32),
#  array([0.6917392], dtype=float32),
#  array([0.6916961], dtype=float32),
#  array([0.69165456], dtype=float32),
#  array([0.69161445], dtype=float32),
#  array([0.6915758], dtype=float32),
#  array([0.69153845], dtype=float32),
#  array([0.69150233], dtype=float32),
#  array([0.6914675], dtype=float32),
#  array([0.6914339], dtype=float32),
#  array([0.6914014], dtype=float32),
#  array([0.69137007], dtype=float32),
#  array([0.69133985], dtype=float32),
#  array([0.6913107], dtype=float32),
#  array([0.6912826], dtype=float32),
#  array([0.6912553], dtype=float32),
#  array([0.69122905], dtype=float32),
#  array([0.69120365], dtype=float32),
#  array([0.6911793], dtype=float32),
#  array([0.6911556], dtype=float32),
#  array([0.6911328], dtype=float32),
#  array([0.6911108], dtype=float32),
#  array([0.69108945], dtype=float32),
#  array([0.6910688], dtype=float32),
#  array([0.6910489], dtype=float32),
#  array([0.69102985], dtype=float32),
#  array([0.6910113], dtype=float32),
#  array([0.6909933], dtype=float32),
#  array([0.6909761], dtype=float32),
#  array([0.69095945], dtype=float32),
#  array([0.6909434], dtype=float32),
#  array([0.69092786], dtype=float32),
#  array([0.690913], dtype=float32),
#  array([0.6908985], dtype=float32),
#  array([0.69088453], dtype=float32),
#  array([0.69087106], dtype=float32),
#  array([0.690858], dtype=float32),
#  array([0.69084543], dtype=float32),
#  array([0.6908334], dtype=float32),
#  array([0.69082165], dtype=float32),
#  array([0.6908104], dtype=float32),
#  array([0.6907994], dtype=float32),
#  array([0.6907889], dtype=float32),
#  array([0.69077873], dtype=float32),
#  array([0.69076896], dtype=float32),
#  array([0.6907595], dtype=float32),
#  array([0.6907504], dtype=float32),
#  array([0.69074154], dtype=float32),
#  array([0.6907331], dtype=float32),
#  array([0.6907248], dtype=float32),
#  array([0.69071674], dtype=float32),
#  array([0.6907091], dtype=float32),
#  array([0.69070166], dtype=float32),
#  array([0.6906945], dtype=float32),
#  array([0.6906876], dtype=float32)]

# %%
lstm_predictions = scaler.inverse_transform(lstm_predictions_scaled)
lstm_predictions
# Out:
# array([[640.60676429],
#        [634.80007113],
#        [630.57562179],
#        [626.96720603],
#        [623.65654207],
#        [620.54744547],
#        [617.59119079],
#        [614.75684971],
#        [612.02739164],
#        [609.39521782],
#        [606.85842856],
#        [604.41749045],
#        [602.07396989],
#        [599.8287001 ],
#        [597.68168106],
#        [595.63184628],
#        [593.67706279],
#        [591.81409776],
#        [590.03938511],
#        [588.34865886],
#        [586.73771969],
#        [585.20206833],
#        [583.73740548],
#        [582.33969845],
#        [581.00511453],
#        [579.72998766],
#        [578.5109517 ],
#        [577.34504048],
#        [576.22938778],
#        [575.16136071],
#        [574.13842634],
#        [573.15845167],
#        [572.21933706],
#        [571.31901617],
#        [570.45575594],
#        [569.62765669],
#        [568.8332853 ],
#        [568.0709754 ],
#        [567.33926054],
#        [566.63680761],
#        [565.96228349],
#        [565.31445505],
#        [564.69212248],
#        [564.09415263],
#        [563.51964565],
#        [562.9673684 ],
#        [562.43652102],
#        [561.92613699],
#        [561.43534979],
#        [560.96335954],
#        [560.50936638],
#        [560.07257044],
#        [559.65230515],
#        [559.24797062],
#        [558.85883363],
#        [558.48429427],
#        [558.12375264],
#        [557.77667551],
#        [557.44242963],
#        [557.12058174],
#        [556.81066525],
#        [556.51214692],
#        [556.22466013],
#        [555.94770497],
#        [555.68088151],
#        [555.42388979],
#        [555.17622989],
#        [554.93760186],
#        [554.70767242],
#        [554.48604164],
#        [554.27244289],
#        [554.06654289],
#        [553.86810835],
#        [553.67683932],
#        [553.49246917],
#        [553.31469796],
#        [553.14335903],
#        [552.97811912],
#        [552.81874492],
#        [552.66513646],
#        [552.51699378],
#        [552.37415024],
#        [552.2363059 ],
#        [552.10339408],
#        [551.97524816],
#        [551.85163485],
#        [551.73242081],
#        [551.61747276],
#        [551.50659071],
#        [551.39957471],
#        [551.29639141],
#        [551.19674088],
#        [551.10072309],
#        [551.0080381 ],
#        [550.91858592],
#        [550.83229989],
#        [550.7490467 ],
#        [550.6687597 ],
#        [550.59123892],
#        [550.51645103],
#        [550.44429604],
#        [550.37460733],
#        [550.30741821],
#        [550.24256204],
#        [550.17997217],
#        [550.11958195],
#        [550.06129139],
#        [550.00506716],
#        [549.95080928],
#        [549.89845109],
#        [549.84789261],
#        [549.79910051],
#        [549.75204146],
#        [549.70654883],
#        [549.66265593],
#        [549.6202628 ],
#        [549.57936942],
#        [549.53994247],
#        [549.50181531],
#        [549.46512125],
#        [549.42966033],
#        [549.39536588],
#        [549.36227124],
#        [549.33040973],
#        [549.29961472],
#        [549.26991952],
#        [549.24119084],
#        [549.21349533],
#        [549.18673299],
#        [549.16087051],
#        [549.13597454],
#        [549.11187845],
#        [549.08864887],
#        [549.06621917],
#        [549.04462267],
#        [549.02372605],
#        [549.00352932],
#        [548.98406581],
#        [548.96526885],
#        [548.94710512],
#        [548.92957463],
#        [548.91267737],
#        [548.89638   ],
#        [548.88064922],
#        [548.86538502],
#        [548.85072073],
#        [548.83652303],
#        [548.8228919 ],
#        [548.80966071],
#        [548.79689611],
#        [548.7845981 ],
#        [548.7726667 ],
#        [548.76113524],
#        [548.7500037 ],
#        [548.73933876],
#        [548.72897378],
#        [548.71890874],
#        [548.70927697],
#        [548.69997847],
#        [548.69101326],
#        [548.68231466],
#        [548.67401601],
#        [548.66588399],
#        [548.65808525],
#        [548.65055314],
#        [548.64325432],
#        [548.63622213],
#        [548.62948988],
#        [548.62292428],
#        [548.6166253 ],
#        [548.61049296],
#        [548.60462724],
#        [548.59892817],
#        [548.59346238],
#        [548.58816324],
#        [548.5830974 ],
#        [548.57813153],
#        [548.57339897],
#        [548.56876638],
#        [548.56426711],
#        [548.56000113],
#        [548.55583514],
#        [548.55183579],
#        [548.54796975]])

# %%
test_w['LSTM_Predictions'] = lstm_predictions
test_w
# Out:
#              Close  LSTM_Predictions
# Date
# 2022-01-18  633.30        640.606764
# 2022-01-19  621.15        634.800071
# 2022-01-20  615.20        630.575622
# 2022-01-21  605.05        626.967206
# 2022-01-24  572.75        623.656542
# ...            ...               ...
# 2022-10-10  411.30        548.564267
# 2022-10-11  404.40        548.560001
# 2022-10-12  407.95        548.555835
# 2022-10-13  379.10        548.551836
# 2022-10-14  377.30        548.547970
#
# [184 rows x 2 columns]

# %%
test_w['Close'].plot(figsize=(20,10), legend = True)
test_w['LSTM_Predictions'].plot(legend = True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
from statsmodels.tools.eval_measures import rmse
lstm_rmse_error = rmse(test_w['Close'], test_w["LSTM_Predictions"])
lstm_mse_error = lstm_rmse_error**2
mean_value = close_W['Close'].mean()

print(f'MSE Error: {lstm_mse_error}\nRMSE Error: {lstm_rmse_error}\nMean: {mean_value}')
# Out:
# MSE Error: 9935.722198560314
# RMSE Error: 99.67809287180566
# Mean: 431.9383454106277

# %% [markdown]
# ## Prophet

# %%
close_W.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2484 entries, 2012-10-01 to 2022-10-14
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   2484 non-null   float64
# dtypes: float64(1)
# memory usage: 38.8 KB

# %%
w_pr = close_W.copy()

# %%
w_pr = close_W.reset_index()

# %%
w_pr.columns = ['ds', 'y']

# %%
train_w_pr = w_pr.iloc[:len(close_W)-30]
test_w_pr = w_pr.iloc[len(close_W)-30:]

# %%
test_w_pr
# Out:
#              ds       y
# 2454 2022-09-02  407.70
# 2455 2022-09-05  405.50
# 2456 2022-09-06  404.45
# 2457 2022-09-07  407.45
# 2458 2022-09-08  412.80
# 2459 2022-09-09  417.15
# 2460 2022-09-12  422.00
# 2461 2022-09-13  422.65
# 2462 2022-09-14  416.30
# 2463 2022-09-15  415.05
# 2464 2022-09-16  401.65
# 2465 2022-09-19  401.95
# 2466 2022-09-20  404.90
# 2467 2022-09-21  400.75
# 2468 2022-09-22  397.95
# 2469 2022-09-23  394.35
# 2470 2022-09-26  394.80
# 2471 2022-09-27  398.40
# 2472 2022-09-28  398.05
# 2473 2022-09-29  392.80
# 2474 2022-09-30  394.25
# 2475 2022-10-03  394.50
# 2476 2022-10-04  405.50
# 2477 2022-10-06  410.15
# 2478 2022-10-07  408.10
# 2479 2022-10-10  411.30
# 2480 2022-10-11  404.40
# 2481 2022-10-12  407.95
# 2482 2022-10-13  379.10
# 2483 2022-10-14  377.30

# %%
# !pip install prophet
from prophet import Prophet
# Out:
# Requirement already satisfied: prophet in c:\users\shriprada\anaconda3\lib\site-packages (1.1.1)
# Requirement already satisfied: LunarCalendar>=0.0.9 in c:\users\shriprada\anaconda3\lib\site-packages (from prophet) (0.0.9)
# Requirement already satisfied: setuptools-git>=1.2 in c:\users\shriprada\anaconda3\lib\site-packages (from prophet) (1.2)
# Requirement already satisfied: holidays>=0.14.2 in c:\users\shriprada\anaconda3\lib\site-packages (from prophet) (0.16)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\shriprada\anaconda3\lib\site-packages (from prophet) (3.5.1)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\shriprada\anaconda3\lib\site-packages (from prophet) (1.21.5)
# Requirement already satisfied: setuptools>=42 in c:\users\shriprada\anaconda3\lib\site-packages (from prophet) (61.2.0)
# Requirement already satisfied: wheel>=0.37.0 in c:\users\shriprada\anaconda3\lib\site-packages (from prophet) (0.37.1)
# Requirement already satisfied: tqdm>=4.36.1 in c:\users\shriprada\anaconda3\lib\site-packages (from prophet) (4.64.0)
# Requirement already satisfied: cmdstanpy>=1.0.4 in c:\users\shriprada\anaconda3\lib\site-packages (from prophet) (1.0.7)
# Requirement already satisfied: pandas>=1.0.4 in c:\users\shriprada\anaconda3\lib\site-packages (from prophet) (1.4.2)
# Requirement already satisfied: convertdate>=2.1.2 in c:\users\shriprada\anaconda3\lib\site-packages (from prophet) (2.4.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\shriprada\anaconda3\lib\site-packages (from prophet) (2.8.2)
# Requirement already satisfied: ujson in c:\users\shriprada\anaconda3\lib\site-packages (from cmdstanpy>=1.0.4->prophet) (5.1.0)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in c:\users\shriprada\anaconda3\lib\site-packages (from convertdate>=2.1.2->prophet) (0.5.11)
# Requirement already satisfied: hijri-converter in c:\users\shriprada\anaconda3\lib\site-packages (from holidays>=0.14.2->prophet) (2.2.4)
# Requirement already satisfied: korean-lunar-calendar in c:\users\shriprada\anaconda3\lib\site-packages (from holidays>=0.14.2->prophet) (0.3.1)
# Requirement already satisfied: pytz in c:\users\shriprada\anaconda3\lib\site-packages (from LunarCalendar>=0.0.9->prophet) (2021.3)
# Requirement already satisfied: ephem>=3.7.5.3 in c:\users\shriprada\anaconda3\lib\site-packages (from LunarCalendar>=0.0.9->prophet) (4.1.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shriprada\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\shriprada\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\shriprada\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\shriprada\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\shriprada\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (9.0.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\shriprada\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (21.3)
# Requirement already satisfied: six>=1.5 in c:\users\shriprada\anaconda3\lib\site-packages (from python-dateutil>=2.8.0->prophet) (1.16.0)
# Requirement already satisfied: colorama in c:\users\shriprada\anaconda3\lib\site-packages (from tqdm>=4.36.1->prophet) (0.4.4)

# %%
df_w = Prophet()
df_w.fit(train_w_pr) 
future = df_w.make_future_dataframe(periods = 30, freq='MS')
prophet_pred_w = df_w.predict(future)
# Out:
# 17:36:29 - cmdstanpy - INFO - Chain [1] start processing
# 17:36:33 - cmdstanpy - INFO - Chain [1] done processing

# %%
prophet_pred_w
# Out:
#              ds        trend  yhat_lower   yhat_upper  trend_lower  \
# 0    2012-10-01   332.451327  275.394558   422.405292   332.451327
# 1    2012-10-03   333.170811  269.966191   426.982597   333.170811
# 2    2012-10-04   333.530553  278.860941   422.227056   333.530553
# 3    2012-10-05   333.890295  272.393176   432.619533   333.890295
# 4    2012-10-08   334.969521  281.408256   431.040862   334.969521
# ...         ...          ...         ...          ...          ...
# 2479 2024-11-01   965.474149  819.927757  1123.204694   835.324982
# 2480 2024-12-01   977.920086  809.276205  1138.235776   839.972594
# 2481 2025-01-01   990.780887  850.773289  1187.253994   842.948650
# 2482 2025-02-01  1003.641688  854.618539  1203.365445   846.369317
# 2483 2025-03-01  1015.257895  844.579722  1221.413016   849.034903
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0      332.451327       19.778165             19.778165             19.778165
# 1      333.170811       19.156853             19.156853             19.156853
# 2      333.530553       18.471509             18.471509             18.471509
# 3      333.890295       18.719938             18.719938             18.719938
# 4      334.969521       21.028288             21.028288             21.028288
# ...           ...             ...                   ...                   ...
# 2479  1100.222658       13.223022             13.223022             13.223022
# 2480  1118.295866       -7.708530             -7.708530             -7.708530
# 2481  1138.539176       31.443248             31.443248             31.443248
# 2482  1157.375312       21.704932             21.704932             21.704932
# 2483  1180.702730       21.592234             21.592234             21.592234
#
#          weekly  weekly_lower  weekly_upper     yearly  yearly_lower  \
# 0      4.572133      4.572133      4.572133  15.206032     15.206032
# 1      3.705613      3.705613      3.705613  15.451240     15.451240
# 2      2.861232      2.861232      2.861232  15.610277     15.610277
# 3      2.926583      2.926583      2.926583  15.793356     15.793356
# 4      4.572133      4.572133      4.572133  16.456156     16.456156
# ...         ...           ...           ...        ...           ...
# 2479   2.926583      2.926583      2.926583  10.296440     10.296440
# 2480 -16.647966    -16.647966    -16.647966   8.939435      8.939435
# 2481   3.705613      3.705613      3.705613  27.737635     27.737635
# 2482  -1.745732     -1.745732     -1.745732  23.450665     23.450665
# 2483  -1.745732     -1.745732     -1.745732  23.337967     23.337967
#
#       yearly_upper  multiplicative_terms  multiplicative_terms_lower  \
# 0        15.206032                   0.0                         0.0
# 1        15.451240                   0.0                         0.0
# 2        15.610277                   0.0                         0.0
# 3        15.793356                   0.0                         0.0
# 4        16.456156                   0.0                         0.0
# ...            ...                   ...                         ...
# 2479     10.296440                   0.0                         0.0
# 2480      8.939435                   0.0                         0.0
# 2481     27.737635                   0.0                         0.0
# 2482     23.450665                   0.0                         0.0
# 2483     23.337967                   0.0                         0.0
#
#       multiplicative_terms_upper         yhat
# 0                            0.0   352.229492
# 1                            0.0   352.327664
# 2                            0.0   352.002062
# 3                            0.0   352.610234
# 4                            0.0   355.997810
# ...                          ...          ...
# 2479                         0.0   978.697171
# 2480                         0.0   970.211555
# 2481                         0.0  1022.224135
# 2482                         0.0  1025.346620
# 2483                         0.0  1036.850130
#
# [2484 rows x 19 columns]

# %%
prophet_pred_w = pd.DataFrame({'Date': prophet_pred_w[-30:]['ds'], 'Pred': prophet_pred_w[-30:]['yhat']})

# %%
prophet_pred_w = prophet_pred_w.set_index('Date')

# %%
prophet_pred_w.index.freq = 'MS'

# %%
prophet_pred_w
# Out:
#                    Pred
# Date
# 2022-10-01   662.760240
# 2022-11-01   677.205267
# 2022-12-01   686.390917
# 2023-01-01   698.159916
# 2023-02-01   727.578711
# 2023-03-01   739.342595
# 2023-04-01   732.529303
# 2023-05-01   723.091209
# 2023-06-01   737.064131
# 2023-07-01   713.334976
# 2023-08-01   757.405389
# 2023-09-01   779.827497
# 2023-10-01   799.261648
# 2023-11-01   828.195788
# 2023-12-01   837.847878
# 2024-01-01   870.576951
# 2024-02-01   878.189030
# 2024-03-01   889.938193
# 2024-04-01   890.755405
# 2024-05-01   873.229012
# 2024-06-01   883.885921
# 2024-07-01   871.327436
# 2024-08-01   908.141124
# 2024-09-01   913.329558
# 2024-10-01   972.147518
# 2024-11-01   978.697171
# 2024-12-01   970.211555
# 2025-01-01  1022.224135
# 2025-02-01  1025.346620
# 2025-03-01  1036.850130

# %%
test_w_pr['Prophet_prediction'] = prophet_pred_w['Pred'].values
test_w_pr
# Out:
# C:\Users\Shriprada\AppData\Local\Temp\ipykernel_22804\3425194532.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_w_pr['Prophet_prediction'] = prophet_pred_w['Pred'].values
#              ds       y  Prophet_prediction
# 2454 2022-09-02  407.70          662.760240
# 2455 2022-09-05  405.50          677.205267
# 2456 2022-09-06  404.45          686.390917
# 2457 2022-09-07  407.45          698.159916
# 2458 2022-09-08  412.80          727.578711
# 2459 2022-09-09  417.15          739.342595
# 2460 2022-09-12  422.00          732.529303
# 2461 2022-09-13  422.65          723.091209
# 2462 2022-09-14  416.30          737.064131
# 2463 2022-09-15  415.05          713.334976
# 2464 2022-09-16  401.65          757.405389
# 2465 2022-09-19  401.95          779.827497
# 2466 2022-09-20  404.90          799.261648
# 2467 2022-09-21  400.75          828.195788
# 2468 2022-09-22  397.95          837.847878
# 2469 2022-09-23  394.35          870.576951
# 2470 2022-09-26  394.80          878.189030
# 2471 2022-09-27  398.40          889.938193
# 2472 2022-09-28  398.05          890.755405
# 2473 2022-09-29  392.80          873.229012
# 2474 2022-09-30  394.25          883.885921
# 2475 2022-10-03  394.50          871.327436
# 2476 2022-10-04  405.50          908.141124
# 2477 2022-10-06  410.15          913.329558
# 2478 2022-10-07  408.10          972.147518
# 2479 2022-10-10  411.30          978.697171
# 2480 2022-10-11  404.40          970.211555
# 2481 2022-10-12  407.95         1022.224135
# 2482 2022-10-13  379.10         1025.346620
# 2483 2022-10-14  377.30         1036.850130

# %%
import seaborn as sns

# %%
plt.figure(figsize =(16,5))
ax = sns.lineplot(x = test_w_pr['ds'], y = test_w_pr['Prophet_prediction'])
sns.lineplot(x = test_w_pr['ds'], y = test_w_pr['y']);

# %% [markdown]
# ## SARIMA

# %%
import statsmodels.api as sm

model=sm.tsa.statespace.SARIMAX(close_W['Close'],order=(1, 2, 1),seasonal_order=(1,2,1,12))
results=model.fit()
# Out:
# C:\Users\Shriprada\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Shriprada\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
